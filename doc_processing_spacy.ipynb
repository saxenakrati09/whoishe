# %%
with open('Patient_data.txt', 'r') as f:
    patient = f.readlines()

# %%
import en_coref_md
nlp = en_coref_md.load()

# %%
for i in range(len(patient)):
    print("Paragraph number...", i)
    doc = nlp(patient[i])
    print(doc._.has_coref)
    print(doc._.coref_clusters)
# Out:
# Paragraph number... 0
# True
# [Crestor: [Crestor, Crestor, Crestor, brand Crestor, Crestor, Crestor, Crestor, Crestor], Patient: [Patient, Patient, Patient, she, she, She, her, Her, She, her, her], Her HCP: [Her HCP, her HCP, HCP], No further information: [No further information, This information], Patient: [Patient, she, she], she is fine with the brand Crestor: [she is fine with the brand Crestor, it]]
# Paragraph number... 1
# True
# [Nexium Rx: [Nexium Rx, the Nexium Rx], This medication: [This medication, the medication, the medication], The caller: [The caller, she, She, she, She, She, she, She, She]]
# Paragraph number... 2
# True
# [a consumer who was no longer on the line: [a consumer who was no longer on the line, The consumer, The consumer, The consumer, The consumer], start date: [start date, her, She, her, her, her], her acid reflux: [her acid reflux, her acid reflux]]
# Paragraph number... 3
# True
# [Patient: [Patient, she, She, her, Patient], Nexium: [Nexium, Nexium]]
# Paragraph number... 4
# True
# [XX: [XX, XX], XX and Me: [XX and Me, XX and Me], Text Body: [Text Body, it], Pamela Desjardins Drug:Seroquel XR 400 mg tab: [Pamela Desjardins Drug:Seroquel XR 400 mg tab, she, She, she, she, Her, her, Her, her, Her, her, her, her], Seroquel XR brand: [Seroquel XR brand, it], PS: [PS, PS]]
# Paragraph number... 5
# True
# [The patients daughter: [The patients daughter, her], Patient: [Patient, her, her, Her, the patient, her, her], labs drawn: [labs drawn, Her labs], her oncologist: [her oncologist, him, the oncologist]]
# Paragraph number... 6
# True
# [Patients husband: [Patients husband, she, He, her]]
# Paragraph number... 7
# True
# [Symbicort: [Symbicort, Symbicort, Symbicort, Symbicort, Symbicort, Symbicort, Symbicort], her: [her, She], allergic symptom of Symbicort: [allergic symptom of Symbicort, it], Dermatologist: [Dermatologist, She, She, she, her, her, She, her, her], a female patient: [a female patient, The patient], her oropharynx: [her oropharynx, her oropharynx], a doctor: [a doctor, the doctor]]

# %% [markdown]
# ## Spacy modules testing

# %% [markdown]
# ### Linguistics Annotations

# %% [markdown]
# spaCy provides a variety of linguistic annotations to give you insights into a text's grammatical structure. This includes the word types, like the parts of speech, and how the words are related to each other. For example, if you're analysing text, it makes a huge difference whether a noun is the subject of a sentence, or the object – or whether "google" is used as a verb, or refers to the website or company in a specific context.

# %%
for i in range(len(patient)):
    print("Paragraph number...", i)
    doc = nlp(patient[i])
    for token in doc:
        print(token.text, token.pos_, token.dep_)
# Out:
# Paragraph number... 0
# Call NOUN nsubj
# came VERB ROOT
# directly ADV advmod
# to ADP prep
# the DET det
# IC PROPN pobj
# for ADP prep
# medical ADJ amod
# inquiry NOUN pobj
# and CCONJ cc
# adverse ADJ amod
# event NOUN conj
# noted VERB advcl
# for ADP prep
# Crestor PROPN pobj
# . PUNCT punct
# Patient NOUN nsubj
# started VERB ROOT
# Crestor PROPN dobj
# 10 NUM nummod
# mg NOUN npadvmod
# daily ADV advmod
# by ADP prep
# mouth NOUN pobj
# in ADP prep
# 01 NUM nummod
# - SYM punct
# 2008 NUM pobj
# for ADP prep
# high ADJ amod
# cholesterol NOUN pobj
# . PUNCT punct
# Patient NOUN nsubj
# also ADV advmod
# taking VERB csubj
# Toprol PROPN compound
# XL PROPN dobj
# 50 NUM nummod
# mg NOUN dobj
# daily ADV advmod
# by ADP prep
# mouth NOUN pobj
# started VERB ROOT
# in ADP prep
# 11 NUM pobj
# - SYM punct
# 2000 NUM prep
# for ADP prep
# high ADJ amod
# blood NOUN compound
# pressure NOUN pobj
# . PUNCT punct
# Patient NOUN nsubj
# reported VERB ROOT
# the DET det
# following NOUN dobj
# that ADP mark
# she PRON nsubj
# has VERB aux
# skipped VERB ccomp
# doses NOUN dobj
# of ADP prep
# Crestor PROPN pobj
# over ADP prep
# the DET det
# years NOUN pobj
# since ADP mark
# she PRON nsubj
# started VERB advcl
# taking VERB xcomp
# it PRON dobj
# and CCONJ cc
# the DET det
# last ADJ amod
# time NOUN nsubj
# was VERB conj
# in ADP prep
# 12 NUM pobj
# - SYM punct
# 2017 NUM prep
# . PUNCT punct
# She PRON nsubj
# would VERB aux
# just ADV advmod
# take VERB ROOT
# her ADJ dobj
# usual ADJ amod
# dose ADP dobj
# the DET det
# next ADJ amod
# day NOUN npadvmod
# and CCONJ cc
# not ADV neg
# try VERB conj
# to PART aux
# make VERB xcomp
# up PART prt
# the DET det
# missed VERB amod
# dose NOUN dobj
# . PUNCT punct
# Her ADJ poss
# HCP PROPN nsubj
# is VERB ROOT
# aware ADJ acomp
# , PUNCT punct
# no DET det
# treatment NOUN npadvmod
# offered VERB acl
# . PUNCT punct
# Had VERB ROOT
# high ADJ amod
# cholesterol NOUN dobj
# since ADP prep
# about ADV advmod
# 2003 NUM pobj
# and CCONJ cc
# currently ADV advmod
# taking VERB advcl
# brand NOUN compound
# Crestor PROPN dobj
# . PUNCT punct
# She PRON nsubj
# is VERB ROOT
# nervous ADJ acomp
# now ADV advmod
# about ADP prep
# taking VERB pcomp
# new ADJ amod
# medications NOUN dobj
# , PUNCT punct
# unknown ADJ amod
# start NOUN compound
# date NOUN appos
# and CCONJ cc
# if ADP mark
# her ADJ poss
# HCP PROPN nsubj
# is VERB conj
# aware ADJ acomp
# . PUNCT punct
# Patient NOUN ROOT
# to PART aux
# start VERB relcl
# generic ADJ amod
# Crestor PROPN dobj
# when ADV advmod
# finish VERB advcl
# her ADJ poss
# brand NOUN compound
# Crestor PROPN dobj
# . PUNCT punct
# No DET det
# further ADJ amod
# information NOUN nsubjpass
# was VERB auxpass
# provided VERB ROOT
# . PUNCT punct
# Follow VERB ROOT
# up PART prt
# received VERB xcomp
# on ADP prep
# 03 NUM nummod
# - PUNCT punct
# 01 NUM nummod
# - PUNCT punct
# 2018 NUM pobj
# . PUNCT punct
# Updated VERB ROOT
# on ADP prep
# 03 NUM nummod
# - PUNCT punct
# 01 NUM nummod
# - PUNCT punct
# 2018 NUM pobj
# . PUNCT punct
# The DET det
# following VERB nsubjpass
# should VERB aux
# have VERB aux
# been VERB auxpass
# included VERB ROOT
# in ADP prep
# the DET det
# above ADJ amod
# narrative NOUN pobj
# . PUNCT punct
# Patient NOUN nsubj
# stated VERB ccomp
# that ADP mark
# she PRON nsubj
# is VERB ccomp
# fine ADJ acomp
# with ADP prep
# the DET det
# brand NOUN compound
# Crestor PROPN pobj
# , PUNCT punct
# she PRON nsubj
# no DET det
# problems NOUN ROOT
# with ADP prep
# it PRON pobj
# . PUNCT punct
# This DET det
# information NOUN nsubjpass
# was VERB auxpass
# received VERB ROOT
# in ADP prep
# the DET det
# original ADJ amod
# phone NOUN compound
# call NOUN pobj
# . PUNCT punct
# Same ADJ amod
# sender NOUN compound
# table NOUN ROOT
# . PUNCT punct
#
#  SPACE
# Paragraph number... 1
# Call VERB ROOT
# direct ADJ oprd
# to ADP prep
# IC PROPN pobj
# with ADP prep
# XX PROPN pobj
# and CCONJ cc
# Me PRON conj
# related ADJ amod
# issue NOUN compound
# removal NOUN dobj
# of ADP prep
# product NOUN compound
# letter NOUN pobj
# . PUNCT punct
# Patient NOUN nsubjpass
# has VERB aux
# been VERB auxpass
# prescribed VERB ROOT
# Nexium PROPN compound
# Rx PROPN compound
# capsule NOUN dobj
# . PUNCT punct
# Long ADJ amod
# term NOUN nsubj
# use VERB ROOT
# Nexium PROPN compound
# Rx PROPN dobj
# . PUNCT punct
# Event NOUN nsubj
# is VERB ROOT
# she PRON nsubj
# took VERB ccomp
# another DET det
# medication NOUN compound
# UNK PROPN dobj
# not ADV neg
# specified VERB acl
# which ADJ nsubj
# did VERB aux
# not ADV neg
# help VERB ccomp
# . PUNCT punct
# This DET det
# medication NOUN nsubj
# was VERB ROOT
# for ADP prep
# a DET det
# medical ADJ amod
# condition NOUN pobj
# not ADV neg
# specified VERB acl
# . PUNCT punct
# The DET det
# caller NOUN nsubj
# was VERB ROOT
# not ADV neg
# sure ADJ acomp
# why ADV advmod
# she PRON nsubj
# took VERB ccomp
# the DET det
# medication NOUN dobj
# . PUNCT punct
# It PRON nsubj
# was VERB ROOT
# possibly ADV advmod
# for ADP prep
# anxiety NOUN pobj
# or CCONJ cc
# depression NOUN conj
# . PUNCT punct
# She PRON nsubj
# noticed VERB ROOT
# the DET det
# medication NOUN nsubj
# did VERB aux
# not ADV neg
# work VERB ccomp
# after ADP mark
# she PRON nsubj
# started VERB advcl
# the DET det
# Nexium PROPN compound
# Rx PROPN dobj
# . PUNCT punct
# She PRON nsubj
# stated VERB ROOT
# Nexium PROPN compound
# Rx PROPN nsubj
# is VERB ccomp
# the DET det
# only ADJ amod
# thing NOUN attr
# that ADJ nsubj
# helps VERB relcl
# . PUNCT punct
# She PRON nsubj
# stated VERB ROOT
# that ADP mark
# in ADP prep
# the DET det
# past NOUN pobj
# she PRON nsubj
# has VERB aux
# had VERB ccomp
# a DET det
# flare NOUN dobj
# up PART prt
# due ADP amod
# to ADP pcomp
# stress NOUN pobj
# or CCONJ cc
# due ADJ conj
# to ADP prep
# being VERB pcomp
# on ADP prep
# an DET det
# antibiotic NOUN pobj
# or CCONJ cc
# eating VERB conj
# certain ADJ amod
# foods NOUN dobj
# . PUNCT punct
# She PRON nsubj
# declined VERB ROOT
# to PART aux
# provide VERB xcomp
# any DET det
# additional ADJ amod
# information NOUN dobj
# for ADP prep
# this DET det
# report NOUN pobj
# . PUNCT punct
# Dates NOUN nsubjpass
# could VERB aux
# not ADV neg
# be VERB auxpass
# clarified VERB ROOT
# . PUNCT punct
# She PRON nsubj
# declined VERB ROOT
# follow VERB xcomp
# up PART prt
# from ADP prep
# patient ADJ compound
# safety NOUN pobj
# and CCONJ cc
# for ADP conj
# permission NOUN pobj
# to PART aux
# contact VERB acl
# HCP PROPN dobj
# . PUNCT punct
# SJ PROPN ROOT
# ( PUNCT punct
# TMS PROPN appos
# ) PUNCT punct
# . PUNCT punct
#
#  SPACE
# Paragraph number... 2
# XX INTJ nmod
# and CCONJ cc
# Me PRON conj
# agent NOUN nsubj
# called VERB ROOT
# to PART aux
# report VERB xcomp
# an DET det
# adverse ADJ amod
# event NOUN dobj
# on ADP prep
# behalf NOUN pobj
# of ADP prep
# a DET det
# consumer NOUN pobj
# who NOUN nsubj
# was VERB relcl
# no ADV neg
# longer ADV advmod
# on ADP prep
# the DET det
# line NOUN pobj
# . PUNCT punct
# The DET det
# consumer NOUN nsubj
# began VERB ccomp
# Nexium PROPN dobj
# 40 NUM nummod
# mg NOUN npadvmod
# once ADV advmod
# a DET det
# day NOUN npadvmod
# , PUNCT punct
# for ADP prep
# acid ADJ amod
# reflux NOUN pobj
# , PUNCT punct
# start VERB compound
# date NOUN nsubj
# not ADV neg
# reported VERB ROOT
# . PUNCT punct
# The DET det
# consumer NOUN nsubj
# reported VERB ROOT
# that ADP mark
# her ADJ poss
# acid ADJ compound
# reflux NOUN nsubj
# was VERB ccomp
# worse ADJ acomp
# past ADJ amod
# couple NOUN nummod
# days NOUN npadvmod
# . PUNCT punct
# She PRON nsubj
# reported VERB ccomp
# having VERB xcomp
# extreme ADJ amod
# stress NOUN dobj
# , PUNCT punct
# heart NOUN nsubj
# burn VERB ROOT
# and CCONJ cc
# is VERB aux
# not ADV neg
# eating VERB conj
# . PUNCT punct
# The DET det
# consumer NOUN nsubj
# further ADV advmod
# clarified VERB ROOT
# that ADP mark
# because ADP prep
# of ADP pcomp
# her ADJ poss
# acid ADJ compound
# reflux NOUN nsubj
# getting VERB pcomp
# worse ADV acomp
# her ADJ poss
# doctor NOUN nsubj
# increased VERB ccomp
# her ADJ poss
# dose NOUN dobj
# to ADP prep
# Nexium PROPN pobj
# 40 NUM nummod
# mg NOUN npadvmod
# twice ADJ advmod
# a DET det
# day NOUN npadvmod
# starting VERB advcl
# today NOUN npadvmod
# . PUNCT punct
# The DET det
# consumer NOUN nsubj
# was VERB ROOT
# no ADV neg
# longer ADV advmod
# on ADP prep
# the DET det
# line NOUN pobj
# and CCONJ cc
# was VERB conj
# unable ADJ acomp
# to PART aux
# provide VERB xcomp
# additional ADJ amod
# information NOUN dobj
# . PUNCT punct
#
#  SPACE
# Paragraph number... 3
# Patient NOUN nsubj
# advised VERB ROOT
# that ADP mark
# she PRON nsubj
# had VERB aux
# taken VERB ccomp
# Nexium PROPN dobj
# in ADP prep
# the DET det
# past NOUN pobj
# the DET nsubjpass
# was VERB auxpass
# switched VERB ccomp
# to ADP prep
# the DET det
# generic ADJ pobj
# and CCONJ cc
# then ADV advmod
# back ADV conj
# to ADP prep
# Nexium PROPN pobj
# . PUNCT punct
# She PRON nsubj
# advised VERB ROOT
# that ADP mark
# the DET det
# generic ADJ nsubj
# does VERB aux
# nt ADV advmod
# work VERB ccomp
# for ADP prep
# her PRON pobj
# . PUNCT punct
# Patient NOUN nsubj
# declined VERB ROOT
# to PART aux
# provide VERB xcomp
# any DET det
# further ADJ amod
# information NOUN dobj
# . PUNCT punct
#
#  SPACE
# Paragraph number... 4
# Email NOUN compound
# correspondence NOUN ROOT
# received VERB acl
# from ADP prep
# XX PROPN pobj
# and CCONJ cc
# Me PRON conj
# . PUNCT punct
# Adverse ADJ amod
# Event NOUN nsubjpass
# was VERB auxpass
# received VERB ccomp
# from ADP prep
# XX PROPN pobj
# and CCONJ cc
# Me PRON conj
# by ADP agent
# email NOUN pobj
# , PUNCT punct
# as ADP mark
# they PRON nsubj
# were VERB advcl
# unable ADJ acomp
# to PART aux
# contact VERB xcomp
# the DET det
# IC PROPN dobj
# by ADP prep
# phone NOUN pobj
# , PUNCT punct
# no DET det
# attachments NOUN nsubjpass
# are VERB auxpass
# associated VERB ROOT
# with ADP prep
# this DET det
# case NOUN pobj
# . PUNCT punct
# Subject NOUN ROOT
# This DET nsubj
# is VERB ROOT
# a DET det
# possible ADJ amod
# AE NOUN attr
# , PUNCT punct
# PQC PROPN conj
# , PUNCT punct
# or CCONJ cc
# Medical PROPN nmod
# / SYM punct
# Product PROPN compound
# Inquiry PROPN conj
# from ADP prep
# XXandMe PROPN compound
# inVentiv PROPN pobj
# . PUNCT punct
# Please INTJ intj
# treat VERB ROOT
# this DET dobj
# as ADP prep
# an DET det
# urgent ADJ amod
# case NOUN pobj
# . PUNCT punct
# AE PROPN nsubj
# received VERB ROOT
# by ADP prep
# phone NOUN pobj
# on ADP prep
# 21 NUM nummod
# - SYM punct
# 09 NUM nummod
# - PUNCT punct
# 2015 NUM pobj
# . PUNCT punct
# Information NOUN nsubjpass
# that ADJ nsubj
# includes VERB relcl
# the DET det
# PERD PROPN compound
# requirements NOUN dobj
# or CCONJ cc
# PQC PROPN compound
# requirements NOUN conj
# is VERB auxpass
# provided VERB ROOT
# . PUNCT punct
# Text PROPN compound
# Body PROPN ROOT
# Date:21 PROPN npadvmod
# - PUNCT punct
# 09 NUM nummod
# - PUNCT punct
# 2015 NUM nummod
# How ADV advmod
# was VERB auxpass
# it PRON nsubjpass
# received VERB ROOT
# : PUNCT punct
# PHONE NOUN compound
# Time NOUN ROOT
# reported:2:50 PROPN compound
# p.m. NOUN appos
# Patient ADJ compound
# information NOUN ROOT
# : PUNCT punct
# Pamela PROPN compound
# Desjardins PROPN appos
# , PUNCT punct
# XX PROPN appos
# , PUNCT punct
# , PUNCT punct
# xxx.xx.0246(DIS PROPN appos
# removed VERB amod
# numbers NOUN appos
# from ADP prep
# Social PROPN compound
# Security PROPN compound
# number NOUN pobj
# and CCONJ cc
# replaced VERB conj
# with ADP prep
# xxx NOUN pobj
# for ADP prep
# privacy NOUN pobj
# ) PUNCT punct
# Event NOUN dep
# : PUNCT punct
# Pt PROPN nsubj
# has VERB aux
# missed VERB ROOT
# 2 NUM nummod
# days NOUN dobj
# of ADP prep
# meds NOUN compound
# Reporter NOUN pobj
# : PUNCT punct
# Pamela PROPN compound
# Desjardins PROPN compound
# Drug PROPN ROOT
# : PUNCT punct
# Seroquel PROPN appos
# XR PROPN appos
# 400 NUM nummod
# mg ADP compound
# tab NOUN appos
# No DET det
# other ADJ amod
# information NOUN nsubj
# provided VERB ROOT
# . PUNCT punct
# No DET det
# permission NOUN nsubj
# provided VERB acl
# for ADP prep
# Patient PROPN compound
# Safety PROPN pobj
# to PART aux
# recontact VERB acl
# Reporter NOUN dobj
# or CCONJ cc
# to PART aux
# contact VERB conj
# HCP.JN(TMS PROPN dobj
# ) PUNCT punct
# Follow VERB ROOT
# up PART prt
# received VERB xcomp
# on ADP prep
# 04 NUM nummod
# - PUNCT punct
# 12 NUM nummod
# - PUNCT punct
# 2017 NUM pobj
# . PUNCT punct
# Enrolled VERB amod
# patient NOUN nsubj
# transferred VERB ROOT
# from ADP prep
# XX PROPN pobj
# and CCONJ cc
# Me PRON conj
# . PUNCT punct
# 2 NUM quantmod
# to ADP quantmod
# 3 NUM nummod
# years NOUN npadvmod
# ago ADV advmod
# she PRON nsubj
# did VERB aux
# not ADV neg
# do VERB ROOT
# well ADV advmod
# on ADP prep
# the DET det
# generic ADJ amod
# Seroquel PROPN compound
# XR PROPN pobj
# , PUNCT punct
# exact ADJ amod
# date NOUN npadvmod
# unknown ADJ advcl
# . PUNCT punct
# She PRON nsubj
# clarified VERB ROOT
# by ADP prep
# stating VERB pcomp
# that ADP mark
# while ADP mark
# she PRON nsubj
# was VERB aux
# using VERB advcl
# the DET det
# generic ADJ dobj
# for ADP prep
# 30 NUM nummod
# days NOUN pobj
# , PUNCT punct
# she PRON nsubj
# did VERB aux
# not ADV neg
# sleep VERB ccomp
# well ADV advmod
# and CCONJ cc
# was VERB conj
# shaky ADJ acomp
# . PUNCT punct
# Her ADJ poss
# HCP PROPN nsubj
# was VERB ROOT
# aware ADJ acomp
# and CCONJ cc
# switched VERB conj
# her PRON dobj
# back ADV advmod
# to ADP prep
# Seroquel PROPN compound
# XR PROPN compound
# brand NOUN pobj
# and CCONJ cc
# those DET det
# symptoms NOUN nsubj
# resolved VERB conj
# . PUNCT punct
# Her ADJ poss
# pharmacist NOUN nsubj
# told VERB ROOT
# her PRON dobj
# it PRON nsubj
# may VERB aux
# have VERB aux
# been VERB ccomp
# due ADJ acomp
# to ADP pcomp
# the DET det
# fillers NOUN pobj
# . PUNCT punct
# PS PROPN nsubj
# granted VERB ROOT
# permission NOUN dobj
# to PART aux
# contact VERB advcl
# patient ADJ dobj
# . PUNCT punct
# Her ADJ poss
# address NOUN nsubj
# is VERB ccomp
# as ADP mark
# stated VERB advcl
# above ADV advmod
# , PUNCT punct
# her ADJ poss
# email NOUN nsubj
# is VERB ROOT
# xxx@yahoo.com X attr
# , PUNCT punct
# and CCONJ cc
# her ADJ poss
# phone NOUN compound
# number NOUN nsubj
# is VERB conj
# 480.300.9210 NUM attr
# . PUNCT punct
# PS PROPN nsubj
# also ADV advmod
# has VERB ROOT
# permission NOUN dobj
# to PART aux
# contact VERB acl
# her ADJ dobj
# HCP PROPN compound
# Dr. PROPN compound
# Michael PROPN compound
# Mar PROPN compound
# practicing VERB dobj
# . PUNCT punct
# No DET det
# further ADJ amod
# information NOUN ROOT
# provided VERB acl
# . PUNCT punct
#
#  SPACE
# Paragraph number... 5
# The DET det
# patients NOUN nsubj
# daughter NOUN appos
# reports VERB ROOT
# her ADJ poss
# mother NOUN nsubj
# has VERB aux
# been VERB aux
# having VERB ccomp
# " PUNCT punct
# abdominal ADJ amod
# burning VERB amod
# pains NOUN dobj
# " PUNCT punct
# since ADP prep
# starting VERB pcomp
# the DET det
# Lynparza PROPN dobj
# . PUNCT punct
# Patient NOUN nsubj
# had VERB ROOT
# labs NOUN dobj
# drawn VERB acl
# and CCONJ cc
# saw VERB conj
# her ADJ poss
# oncologist NOUN dobj
# yesterday NOUN npadvmod
# and CCONJ cc
# informed VERB conj
# him PRON dobj
# of ADP prep
# her ADJ poss
# symptoms NOUN pobj
# . PUNCT punct
# Her ADJ poss
# labs NOUN nsubj
# were VERB ROOT
# all ADV advmod
# okay ADJ acomp
# and CCONJ cc
# the DET det
# oncologist NOUN nsubj
# examined VERB conj
# the DET det
# patient NOUN dobj
# but CCONJ cc
# did VERB aux
# not ADV neg
# give VERB conj
# her ADJ dative
# anything NOUN dobj
# for ADP prep
# her ADJ poss
# stomach NOUN pobj
# . PUNCT punct
#
#  SPACE
# Paragraph number... 6
# Patients NOUN compound
# husband NOUN nsubj
# reported VERB ROOT
# she PRON nsubj
# has VERB ccomp
# nausea NOUN dobj
# , PUNCT punct
# vomiting NOUN advcl
# , PUNCT punct
# " PUNCT punct
# ca VERB aux
# nt ADV advmod
# eat VERB conj
# " PUNCT punct
# and CCONJ cc
# is VERB conj
# unable ADJ acomp
# to PART aux
# sleep VERB xcomp
# . PUNCT punct
# He PRON nsubj
# reports VERB ROOT
# that ADP mark
# patients NOUN compound
# labs NOUN nsubj
# have VERB aux
# been VERB ccomp
# okay ADJ acomp
# but CCONJ cc
# her ADJ poss
# RBCs NOUN nsubj
# are VERB conj
# slightly ADV advmod
# low ADJ acomp
# . PUNCT punct
#
#  SPACE
# Paragraph number... 7
# One NUM nummod
# 25 NUM nummod
# years NOUN npadvmod
# old ADJ amod
# female ADJ amod
# patient NOUN nsubj
# received VERB ROOT
# Symbicort PROPN dative
# 160 NUM nummod
# ug PROPN nsubj
# bid NOUN advcl
# for ADP prep
# asthma NOUN pobj
# via ADP prep
# prescription NOUN pobj
# since ADP prep
# over ADP quantmod
# one NUM nummod
# month NOUN npadvmod
# ago ADV pcomp
# . PUNCT punct
# No DET det
# other ADJ amod
# medical ADJ amod
# history NOUN ROOT
# . PUNCT punct
# One NUM nummod
# week NOUN npadvmod
# after ADP prep
# medication NOUN pobj
# her ADJ poss
# face NOUN nsubj
# appeared VERB ROOT
# rash ADJ oprd
# vesicular(little NOUN amod
# blisters NOUN dobj
# accompanying VERB acl
# with ADP prep
# pain NOUN pobj
# ) PUNCT punct
# . PUNCT punct
# She PRON nsubj
# visited VERB ccomp
# pneumology NOUN compound
# department NOUN dobj
# , PUNCT punct
# the DET det
# doctor NOUN nsubj
# said VERB ROOT
# allergic ADJ amod
# symptom NOUN nsubj
# of ADP prep
# Symbicort PROPN pobj
# was VERB auxpass
# rare ADJ acomp
# , PUNCT punct
# it PRON nsubjpass
# was VERB auxpass
# uncertainly ADV advmod
# caused VERB ccomp
# by ADP agent
# Symbicort PROPN pobj
# . PUNCT punct
# Dermatologist NOUN nsubj
# said VERB ROOT
# it PRON nsubjpass
# might VERB aux
# be VERB auxpass
# caused VERB ccomp
# by ADP agent
# hormone NOUN compound
# ingredient NOUN pobj
# of ADP prep
# Symbicort PROPN pobj
# . PUNCT punct
# She PRON nsubj
# smeared VERB ROOT
# Ganciclovir PROPN compound
# Gel PROPN dobj
# and CCONJ cc
# then ADV advmod
# the DET det
# AE PROPN nsubjpass
# was VERB auxpass
# improved VERB conj
# . PUNCT punct
# But CCONJ cc
# rash ADJ compound
# vesicular NOUN nsubj
# would VERB aux
# recur VERB ROOT
# when ADV advmod
# Symbicort PROPN nsubjpass
# was VERB auxpass
# received VERB advcl
# . PUNCT punct
# Fu PROPN dep
# on ADP prep
# 12 NUM nummod
# - SYM punct
# 12 NUM nummod
# - PUNCT punct
# 2017 NUM pobj
# : PUNCT punct
# This DET nsubj
# is VERB ROOT
# a DET det
# follow NOUN attr
# up PART prt
# spontaneous ADJ amod
# report NOUN dobj
# concerning VERB acl
# a DET det
# female ADJ amod
# patient NOUN pobj
# . PUNCT punct
# Concomitant ADJ amod
# medication NOUN nsubjpass
# was VERB auxpass
# not ADV neg
# reported VERB ROOT
# . PUNCT punct
# The DET det
# patient NOUN nsubj
# received VERB ROOT
# Symbicort PROPN dobj
# for ADP prep
# asthma NOUN pobj
# via ADP prep
# prescription NOUN pobj
# . PUNCT punct
# She PRON nsubj
# visited VERB ROOT
# a DET det
# doctor NOUN dobj
# for ADP prep
# examination NOUN pobj
# on ADP prep
# an DET det
# unspecified ADJ amod
# date NOUN pobj
# after ADP mark
# she PRON nsubj
# received VERB advcl
# Symbicort PROPN dobj
# for ADP prep
# a DET det
# period NOUN pobj
# . PUNCT punct
# The DET det
# result NOUN nsubj
# of ADP prep
# tracheoscopy NOUN compound
# examination NOUN pobj
# showed VERB ROOT
# that ADP mark
# there ADV expl
# was VERB ccomp
# candida NOUN compound
# albicans NOUN compound
# infection NOUN attr
# in ADP prep
# her ADJ poss
# lung NOUN pobj
# and CCONJ cc
# the DET det
# result NOUN conj
# of ADP prep
# sputum NOUN compound
# examination NOUN pobj
# showed VERB ccomp
# that ADP mark
# there ADV expl
# was VERB ccomp
# monilial ADJ amod
# infection NOUN attr
# in ADP prep
# her ADJ poss
# oropharynx NOUN pobj
# . PUNCT punct
# She PRON nsubj
# visited VERB ROOT
# a DET det
# doctor NOUN dobj
# and CCONJ cc
# the DET det
# doctor NOUN nsubj
# did VERB aux
# nt ADV advmod
# give VERB conj
# the DET det
# treatment NOUN dobj
# . PUNCT punct
# Information NOUN nsubjpass
# concerning VERB acl
# new ADJ amod
# AEs NOUN dobj
# of ADP prep
# ’candida PROPN compound
# albicans NOUN compound
# infection NOUN pobj
# in ADP prep
# her ADJ poss
# lung NOUN nmod
# and CCONJ cc
# ’monilial ADJ conj
# infection NOUN pobj
# in ADP prep
# her ADJ poss
# oropharynx NOUN pobj
# was VERB auxpass
# added VERB ROOT
# . PUNCT punct
#
#  SPACE

# %% [markdown]
# ### Tokenization

# %% [markdown]
# During processing, spaCy first tokenizes the text, i.e. segments it into words, punctuation and so on. This is done by applying rules specific to each language. For example, punctuation at the end of a sentence should be split off – whereas "U.K." should remain one token. Each Doc consists of individual tokens, and we can iterate over them:

# %%
for i in range(len(patient)):
    print("Paragraph number...", i)
    doc = nlp(patient[i])
    for token in doc:
        print(token.text)
# Out:
# Paragraph number... 0
# Call
# came
# directly
# to
# the
# IC
# for
# medical
# inquiry
# and
# adverse
# event
# noted
# for
# Crestor
# .
# Patient
# started
# Crestor
# 10
# mg
# daily
# by
# mouth
# in
# 01
# -
# 2008
# for
# high
# cholesterol
# .
# Patient
# also
# taking
# Toprol
# XL
# 50
# mg
# daily
# by
# mouth
# started
# in
# 11
# -
# 2000
# for
# high
# blood
# pressure
# .
# Patient
# reported
# the
# following
# that
# she
# has
# skipped
# doses
# of
# Crestor
# over
# the
# years
# since
# she
# started
# taking
# it
# and
# the
# last
# time
# was
# in
# 12
# -
# 2017
# .
# She
# would
# just
# take
# her
# usual
# dose
# the
# next
# day
# and
# not
# try
# to
# make
# up
# the
# missed
# dose
# .
# Her
# HCP
# is
# aware
# ,
# no
# treatment
# offered
# .
# Had
# high
# cholesterol
# since
# about
# 2003
# and
# currently
# taking
# brand
# Crestor
# .
# She
# is
# nervous
# now
# about
# taking
# new
# medications
# ,
# unknown
# start
# date
# and
# if
# her
# HCP
# is
# aware
# .
# Patient
# to
# start
# generic
# Crestor
# when
# finish
# her
# brand
# Crestor
# .
# No
# further
# information
# was
# provided
# .
# Follow
# up
# received
# on
# 03
# -
# 01
# -
# 2018
# .
# Updated
# on
# 03
# -
# 01
# -
# 2018
# .
# The
# following
# should
# have
# been
# included
# in
# the
# above
# narrative
# .
# Patient
# stated
# that
# she
# is
# fine
# with
# the
# brand
# Crestor
# ,
# she
# no
# problems
# with
# it
# .
# This
# information
# was
# received
# in
# the
# original
# phone
# call
# .
# Same
# sender
# table
# .
#
#
# Paragraph number... 1
# Call
# direct
# to
# IC
# with
# XX
# and
# Me
# related
# issue
# removal
# of
# product
# letter
# .
# Patient
# has
# been
# prescribed
# Nexium
# Rx
# capsule
# .
# Long
# term
# use
# Nexium
# Rx
# .
# Event
# is
# she
# took
# another
# medication
# UNK
# not
# specified
# which
# did
# not
# help
# .
# This
# medication
# was
# for
# a
# medical
# condition
# not
# specified
# .
# The
# caller
# was
# not
# sure
# why
# she
# took
# the
# medication
# .
# It
# was
# possibly
# for
# anxiety
# or
# depression
# .
# She
# noticed
# the
# medication
# did
# not
# work
# after
# she
# started
# the
# Nexium
# Rx
# .
# She
# stated
# Nexium
# Rx
# is
# the
# only
# thing
# that
# helps
# .
# She
# stated
# that
# in
# the
# past
# she
# has
# had
# a
# flare
# up
# due
# to
# stress
# or
# due
# to
# being
# on
# an
# antibiotic
# or
# eating
# certain
# foods
# .
# She
# declined
# to
# provide
# any
# additional
# information
# for
# this
# report
# .
# Dates
# could
# not
# be
# clarified
# .
# She
# declined
# follow
# up
# from
# patient
# safety
# and
# for
# permission
# to
# contact
# HCP
# .
# SJ
# (
# TMS
# )
# .
#
#
# Paragraph number... 2
# XX
# and
# Me
# agent
# called
# to
# report
# an
# adverse
# event
# on
# behalf
# of
# a
# consumer
# who
# was
# no
# longer
# on
# the
# line
# .
# The
# consumer
# began
# Nexium
# 40
# mg
# once
# a
# day
# ,
# for
# acid
# reflux
# ,
# start
# date
# not
# reported
# .
# The
# consumer
# reported
# that
# her
# acid
# reflux
# was
# worse
# past
# couple
# days
# .
# She
# reported
# having
# extreme
# stress
# ,
# heart
# burn
# and
# is
# not
# eating
# .
# The
# consumer
# further
# clarified
# that
# because
# of
# her
# acid
# reflux
# getting
# worse
# her
# doctor
# increased
# her
# dose
# to
# Nexium
# 40
# mg
# twice
# a
# day
# starting
# today
# .
# The
# consumer
# was
# no
# longer
# on
# the
# line
# and
# was
# unable
# to
# provide
# additional
# information
# .
#
#
# Paragraph number... 3
# Patient
# advised
# that
# she
# had
# taken
# Nexium
# in
# the
# past
# the
# was
# switched
# to
# the
# generic
# and
# then
# back
# to
# Nexium
# .
# She
# advised
# that
# the
# generic
# does
# nt
# work
# for
# her
# .
# Patient
# declined
# to
# provide
# any
# further
# information
# .
#
#
# Paragraph number... 4
# Email
# correspondence
# received
# from
# XX
# and
# Me
# .
# Adverse
# Event
# was
# received
# from
# XX
# and
# Me
# by
# email
# ,
# as
# they
# were
# unable
# to
# contact
# the
# IC
# by
# phone
# ,
# no
# attachments
# are
# associated
# with
# this
# case
# .
# Subject
# This
# is
# a
# possible
# AE
# ,
# PQC
# ,
# or
# Medical
# /
# Product
# Inquiry
# from
# XXandMe
# inVentiv
# .
# Please
# treat
# this
# as
# an
# urgent
# case
# .
# AE
# received
# by
# phone
# on
# 21
# -
# 09
# -
# 2015
# .
# Information
# that
# includes
# the
# PERD
# requirements
# or
# PQC
# requirements
# is
# provided
# .
# Text
# Body
# Date:21
# -
# 09
# -
# 2015
# How
# was
# it
# received
# :
# PHONE
# Time
# reported:2:50
# p.m.
# Patient
# information
# :
# Pamela
# Desjardins
# ,
# XX
# ,
# ,
# xxx.xx.0246(DIS
# removed
# numbers
# from
# Social
# Security
# number
# and
# replaced
# with
# xxx
# for
# privacy
# )
# Event
# :
# Pt
# has
# missed
# 2
# days
# of
# meds
# Reporter
# :
# Pamela
# Desjardins
# Drug
# :
# Seroquel
# XR
# 400
# mg
# tab
# No
# other
# information
# provided
# .
# No
# permission
# provided
# for
# Patient
# Safety
# to
# recontact
# Reporter
# or
# to
# contact
# HCP.JN(TMS
# )
# Follow
# up
# received
# on
# 04
# -
# 12
# -
# 2017
# .
# Enrolled
# patient
# transferred
# from
# XX
# and
# Me
# .
# 2
# to
# 3
# years
# ago
# she
# did
# not
# do
# well
# on
# the
# generic
# Seroquel
# XR
# ,
# exact
# date
# unknown
# .
# She
# clarified
# by
# stating
# that
# while
# she
# was
# using
# the
# generic
# for
# 30
# days
# ,
# she
# did
# not
# sleep
# well
# and
# was
# shaky
# .
# Her
# HCP
# was
# aware
# and
# switched
# her
# back
# to
# Seroquel
# XR
# brand
# and
# those
# symptoms
# resolved
# .
# Her
# pharmacist
# told
# her
# it
# may
# have
# been
# due
# to
# the
# fillers
# .
# PS
# granted
# permission
# to
# contact
# patient
# .
# Her
# address
# is
# as
# stated
# above
# ,
# her
# email
# is
# xxx@yahoo.com
# ,
# and
# her
# phone
# number
# is
# 480.300.9210
# .
# PS
# also
# has
# permission
# to
# contact
# her
# HCP
# Dr.
# Michael
# Mar
# practicing
# .
# No
# further
# information
# provided
# .
#
#
# Paragraph number... 5
# The
# patients
# daughter
# reports
# her
# mother
# has
# been
# having
# "
# abdominal
# burning
# pains
# "
# since
# starting
# the
# Lynparza
# .
# Patient
# had
# labs
# drawn
# and
# saw
# her
# oncologist
# yesterday
# and
# informed
# him
# of
# her
# symptoms
# .
# Her
# labs
# were
# all
# okay
# and
# the
# oncologist
# examined
# the
# patient
# but
# did
# not
# give
# her
# anything
# for
# her
# stomach
# .
#
#
# Paragraph number... 6
# Patients
# husband
# reported
# she
# has
# nausea
# ,
# vomiting
# ,
# "
# ca
# nt
# eat
# "
# and
# is
# unable
# to
# sleep
# .
# He
# reports
# that
# patients
# labs
# have
# been
# okay
# but
# her
# RBCs
# are
# slightly
# low
# .
#
#
# Paragraph number... 7
# One
# 25
# years
# old
# female
# patient
# received
# Symbicort
# 160
# ug
# bid
# for
# asthma
# via
# prescription
# since
# over
# one
# month
# ago
# .
# No
# other
# medical
# history
# .
# One
# week
# after
# medication
# her
# face
# appeared
# rash
# vesicular(little
# blisters
# accompanying
# with
# pain
# )
# .
# She
# visited
# pneumology
# department
# ,
# the
# doctor
# said
# allergic
# symptom
# of
# Symbicort
# was
# rare
# ,
# it
# was
# uncertainly
# caused
# by
# Symbicort
# .
# Dermatologist
# said
# it
# might
# be
# caused
# by
# hormone
# ingredient
# of
# Symbicort
# .
# She
# smeared
# Ganciclovir
# Gel
# and
# then
# the
# AE
# was
# improved
# .
# But
# rash
# vesicular
# would
# recur
# when
# Symbicort
# was
# received
# .
# Fu
# on
# 12
# -
# 12
# -
# 2017
# :
# This
# is
# a
# follow
# up
# spontaneous
# report
# concerning
# a
# female
# patient
# .
# Concomitant
# medication
# was
# not
# reported
# .
# The
# patient
# received
# Symbicort
# for
# asthma
# via
# prescription
# .
# She
# visited
# a
# doctor
# for
# examination
# on
# an
# unspecified
# date
# after
# she
# received
# Symbicort
# for
# a
# period
# .
# The
# result
# of
# tracheoscopy
# examination
# showed
# that
# there
# was
# candida
# albicans
# infection
# in
# her
# lung
# and
# the
# result
# of
# sputum
# examination
# showed
# that
# there
# was
# monilial
# infection
# in
# her
# oropharynx
# .
# She
# visited
# a
# doctor
# and
# the
# doctor
# did
# nt
# give
# the
# treatment
# .
# Information
# concerning
# new
# AEs
# of
# ’candida
# albicans
# infection
# in
# her
# lung
# and
# ’monilial
# infection
# in
# her
# oropharynx
# was
# added
# .

# %% [markdown]
# ### Part of speech tags and dependencies

# %% [markdown]
# After tokenization, spaCy can parse and tag a given Doc. This is where the statistical model comes in, which enables spaCy to make a prediction of which tag or label most likely applies in this context. A model consists of binary data and is produced by showing a system enough examples for it to make predictions that generalise across the language – for example, a word following "the" in English is most likely a noun.
#
# Linguistic annotations are available as Token attributes . Like many NLP libraries, spaCy encodes all strings to hash values to reduce memory usage and improve efficiency. So to get the readable string representation of an attribute, we need to add an underscore _ to its name:

# %%
for i in range(len(patient)):
    print("Paragraph number...", i)
    doc = nlp(patient[i])
    for token in doc:
        print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
          token.shape_, token.is_alpha, token.is_stop)
# Out:
# Paragraph number... 0
# Call call NOUN NN nsubj Xxxx True False
# came come VERB VBD ROOT xxxx True False
# directly directly ADV RB advmod xxxx True False
# to to ADP IN prep xx True False
# the the DET DT det xxx True False
# IC ic PROPN NNP pobj XX True False
# for for ADP IN prep xxx True False
# medical medical ADJ JJ amod xxxx True False
# inquiry inquiry NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# adverse adverse ADJ JJ amod xxxx True False
# event event NOUN NN conj xxxx True False
# noted note VERB VBN advcl xxxx True False
# for for ADP IN prep xxx True False
# Crestor crestor PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubj Xxxxx True False
# started start VERB VBD ROOT xxxx True False
# Crestor crestor PROPN NNP dobj Xxxxx True False
# 10 10 NUM CD nummod dd False False
# mg mg NOUN NN npadvmod xx True False
# daily daily ADV RB advmod xxxx True False
# by by ADP IN prep xx True False
# mouth mouth NOUN NN pobj xxxx True False
# in in ADP IN prep xx True False
# 01 01 NUM CD nummod dd False False
# - - SYM SYM punct - False False
# 2008 2008 NUM CD pobj dddd False False
# for for ADP IN prep xxx True False
# high high ADJ JJ amod xxxx True False
# cholesterol cholesterol NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubj Xxxxx True False
# also also ADV RB advmod xxxx True False
# taking take VERB VBG csubj xxxx True False
# Toprol toprol PROPN NNP compound Xxxxx True False
# XL xl PROPN NNP dobj XX True False
# 50 50 NUM CD nummod dd False False
# mg mg NOUN NN dobj xx True False
# daily daily ADV RB advmod xxxx True False
# by by ADP IN prep xx True False
# mouth mouth NOUN NN pobj xxxx True False
# started start VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True False
# 11 11 NUM CD pobj dd False False
# - - SYM SYM punct - False False
# 2000 2000 NUM CD prep dddd False False
# for for ADP IN prep xxx True False
# high high ADJ JJ amod xxxx True False
# blood blood NOUN NN compound xxxx True False
# pressure pressure NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubj Xxxxx True False
# reported report VERB VBD ROOT xxxx True False
# the the DET DT det xxx True False
# following following NOUN NN dobj xxxx True False
# that that ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# has have VERB VBZ aux xxx True False
# skipped skip VERB VBN ccomp xxxx True False
# doses dos NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True False
# Crestor crestor PROPN NNP pobj Xxxxx True False
# over over ADP IN prep xxxx True False
# the the DET DT det xxx True False
# years year NOUN NNS pobj xxxx True False
# since since ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# started start VERB VBD advcl xxxx True False
# taking take VERB VBG xcomp xxxx True False
# it -PRON- PRON PRP dobj xx True False
# and and CCONJ CC cc xxx True False
# the the DET DT det xxx True False
# last last ADJ JJ amod xxxx True False
# time time NOUN NN nsubj xxxx True False
# was be VERB VBD conj xxx True False
# in in ADP IN prep xx True False
# 12 12 NUM CD pobj dd False False
# - - SYM SYM punct - False False
# 2017 2017 NUM CD prep dddd False False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# would would VERB MD aux xxxx True False
# just just ADV RB advmod xxxx True False
# take take VERB VB ROOT xxxx True False
# her -PRON- ADJ PRP$ dobj xxx True False
# usual usual ADJ JJ amod xxxx True False
# dose dose ADP IN dobj xxxx True False
# the the DET DT det xxx True False
# next next ADJ JJ amod xxxx True False
# day day NOUN NN npadvmod xxx True False
# and and CCONJ CC cc xxx True False
# not not ADV RB neg xxx True False
# try try VERB VB conj xxx True False
# to to PART TO aux xx True False
# make make VERB VB xcomp xxxx True False
# up up PART RP prt xx True False
# the the DET DT det xxx True False
# missed miss VERB VBN amod xxxx True False
# dose dose NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Her -PRON- ADJ PRP$ poss Xxx True False
# HCP hcp PROPN NNP nsubj XXX True False
# is be VERB VBZ ROOT xx True False
# aware aware ADJ JJ acomp xxxx True False
# , , PUNCT , punct , False False
# no no DET DT det xx True False
# treatment treatment NOUN NN npadvmod xxxx True False
# offered offer VERB VBD acl xxxx True False
# . . PUNCT . punct . False False
# Had have VERB VBD ROOT Xxx True False
# high high ADJ JJ amod xxxx True False
# cholesterol cholesterol NOUN NN dobj xxxx True False
# since since ADP IN prep xxxx True False
# about about ADV RB advmod xxxx True False
# 2003 2003 NUM CD pobj dddd False False
# and and CCONJ CC cc xxx True False
# currently currently ADV RB advmod xxxx True False
# taking take VERB VBG advcl xxxx True False
# brand brand NOUN NN compound xxxx True False
# Crestor crestor PROPN NNP dobj Xxxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# is be VERB VBZ ROOT xx True False
# nervous nervous ADJ JJ acomp xxxx True False
# now now ADV RB advmod xxx True False
# about about ADP IN prep xxxx True False
# taking take VERB VBG pcomp xxxx True False
# new new ADJ JJ amod xxx True False
# medications medication NOUN NNS dobj xxxx True False
# , , PUNCT , punct , False False
# unknown unknown ADJ JJ amod xxxx True False
# start start NOUN NN compound xxxx True False
# date date NOUN NN appos xxxx True False
# and and CCONJ CC cc xxx True False
# if if ADP IN mark xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# HCP hcp PROPN NNP nsubj XXX True False
# is be VERB VBZ conj xx True False
# aware aware ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN ROOT Xxxxx True False
# to to PART TO aux xx True False
# start start VERB VB relcl xxxx True False
# generic generic ADJ JJ amod xxxx True False
# Crestor crestor PROPN NNP dobj Xxxxx True False
# when when ADV WRB advmod xxxx True False
# finish finish VERB VB advcl xxxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# brand brand NOUN NN compound xxxx True False
# Crestor crestor PROPN NNP dobj Xxxxx True False
# . . PUNCT . punct . False False
# No no DET DT det Xx True False
# further further ADJ JJ amod xxxx True False
# information information NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True False
# provided provide VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
# Follow follow VERB VB ROOT Xxxxx True False
# up up PART RP prt xx True False
# received receive VERB VBN xcomp xxxx True False
# on on ADP IN prep xx True False
# 03 03 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 01 01 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 2018 2018 NUM CD pobj dddd False False
# . . PUNCT . punct . False False
# Updated update VERB VBN ROOT Xxxxx True False
# on on ADP IN prep xx True False
# 03 03 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 01 01 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 2018 2018 NUM CD pobj dddd False False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# following follow VERB VBG nsubjpass xxxx True False
# should should VERB MD aux xxxx True False
# have have VERB VB aux xxxx True False
# been be VERB VBN auxpass xxxx True False
# included include VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True False
# the the DET DT det xxx True False
# above above ADJ JJ amod xxxx True False
# narrative narrative NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubj Xxxxx True False
# stated state VERB VBD ccomp xxxx True False
# that that ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# is be VERB VBZ ccomp xx True False
# fine fine ADJ JJ acomp xxxx True False
# with with ADP IN prep xxxx True False
# the the DET DT det xxx True False
# brand brand NOUN NN compound xxxx True False
# Crestor crestor PROPN NNP pobj Xxxxx True False
# , , PUNCT , punct , False False
# she -PRON- PRON PRP nsubj xxx True False
# no no DET DT det xx True False
# problems problem NOUN NNS ROOT xxxx True False
# with with ADP IN prep xxxx True False
# it -PRON- PRON PRP pobj xx True False
# . . PUNCT . punct . False False
# This this DET DT det Xxxx True False
# information information NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True False
# received receive VERB VBN ROOT xxxx True False
# in in ADP IN prep xx True False
# the the DET DT det xxx True False
# original original ADJ JJ amod xxxx True False
# phone phone NOUN NN compound xxxx True False
# call call NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Same same ADJ JJ amod Xxxx True False
# sender sender NOUN NN compound xxxx True False
# table table NOUN NN ROOT xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 1
# Call call VERB VB ROOT Xxxx True False
# direct direct ADJ JJ oprd xxxx True False
# to to ADP IN prep xx True False
# IC ic PROPN NNP pobj XX True False
# with with ADP IN prep xxxx True False
# XX xx PROPN NNP pobj XX True False
# and and CCONJ CC cc xxx True False
# Me -PRON- PRON PRP conj Xx True False
# related related ADJ JJ amod xxxx True False
# issue issue NOUN NN compound xxxx True False
# removal removal NOUN NN dobj xxxx True False
# of of ADP IN prep xx True False
# product product NOUN NN compound xxxx True False
# letter letter NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubjpass Xxxxx True False
# has have VERB VBZ aux xxx True False
# been be VERB VBN auxpass xxxx True False
# prescribed prescribe VERB VBN ROOT xxxx True False
# Nexium nexium PROPN NNP compound Xxxxx True False
# Rx rx PROPN NNP compound Xx True False
# capsule capsule NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Long long ADJ JJ amod Xxxx True False
# term term NOUN NN nsubj xxxx True False
# use use VERB VB ROOT xxx True False
# Nexium nexium PROPN NNP compound Xxxxx True False
# Rx rx PROPN NNP dobj Xx True False
# . . PUNCT . punct . False False
# Event event NOUN NN nsubj Xxxxx True False
# is be VERB VBZ ROOT xx True False
# she -PRON- PRON PRP nsubj xxx True False
# took take VERB VBD ccomp xxxx True False
# another another DET DT det xxxx True False
# medication medication NOUN NN compound xxxx True False
# UNK unk PROPN NNP dobj XXX True False
# not not ADV RB neg xxx True False
# specified specify VERB VBD acl xxxx True False
# which which ADJ WDT nsubj xxxx True False
# did do VERB VBD aux xxx True False
# not not ADV RB neg xxx True False
# help help VERB VB ccomp xxxx True False
# . . PUNCT . punct . False False
# This this DET DT det Xxxx True False
# medication medication NOUN NN nsubj xxxx True False
# was be VERB VBD ROOT xxx True False
# for for ADP IN prep xxx True False
# a a DET DT det x True False
# medical medical ADJ JJ amod xxxx True False
# condition condition NOUN NN pobj xxxx True False
# not not ADV RB neg xxx True False
# specified specify VERB VBN acl xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# caller caller NOUN NN nsubj xxxx True False
# was be VERB VBD ROOT xxx True False
# not not ADV RB neg xxx True False
# sure sure ADJ JJ acomp xxxx True False
# why why ADV WRB advmod xxx True False
# she -PRON- PRON PRP nsubj xxx True False
# took take VERB VBD ccomp xxxx True False
# the the DET DT det xxx True False
# medication medication NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# It -PRON- PRON PRP nsubj Xx True False
# was be VERB VBD ROOT xxx True False
# possibly possibly ADV RB advmod xxxx True False
# for for ADP IN prep xxx True False
# anxiety anxiety NOUN NN pobj xxxx True False
# or or CCONJ CC cc xx True False
# depression depression NOUN NN conj xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# noticed notice VERB VBD ROOT xxxx True False
# the the DET DT det xxx True False
# medication medication NOUN NN nsubj xxxx True False
# did do VERB VBD aux xxx True False
# not not ADV RB neg xxx True False
# work work VERB VB ccomp xxxx True False
# after after ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# started start VERB VBD advcl xxxx True False
# the the DET DT det xxx True False
# Nexium nexium PROPN NNP compound Xxxxx True False
# Rx rx PROPN NNP dobj Xx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# stated state VERB VBD ROOT xxxx True False
# Nexium nexium PROPN NNP compound Xxxxx True False
# Rx rx PROPN NNP nsubj Xx True False
# is be VERB VBZ ccomp xx True False
# the the DET DT det xxx True False
# only only ADJ JJ amod xxxx True False
# thing thing NOUN NN attr xxxx True False
# that that ADJ WDT nsubj xxxx True False
# helps help VERB VBZ relcl xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# stated state VERB VBD ROOT xxxx True False
# that that ADP IN mark xxxx True False
# in in ADP IN prep xx True False
# the the DET DT det xxx True False
# past past NOUN NN pobj xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# has have VERB VBZ aux xxx True False
# had have VERB VBN ccomp xxx True False
# a a DET DT det x True False
# flare flare NOUN NN dobj xxxx True False
# up up PART RP prt xx True False
# due due ADP IN amod xxx True False
# to to ADP IN pcomp xx True False
# stress stress NOUN NN pobj xxxx True False
# or or CCONJ CC cc xx True False
# due due ADJ JJ conj xxx True False
# to to ADP IN prep xx True False
# being be VERB VBG pcomp xxxx True False
# on on ADP IN prep xx True False
# an an DET DT det xx True False
# antibiotic antibiotic NOUN NN pobj xxxx True False
# or or CCONJ CC cc xx True False
# eating eat VERB VBG conj xxxx True False
# certain certain ADJ JJ amod xxxx True False
# foods food NOUN NNS dobj xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# declined decline VERB VBD ROOT xxxx True False
# to to PART TO aux xx True False
# provide provide VERB VB xcomp xxxx True False
# any any DET DT det xxx True False
# additional additional ADJ JJ amod xxxx True False
# information information NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True False
# this this DET DT det xxxx True False
# report report NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Dates date NOUN NNS nsubjpass Xxxxx True False
# could could VERB MD aux xxxx True False
# not not ADV RB neg xxx True False
# be be VERB VB auxpass xx True False
# clarified clarify VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# declined decline VERB VBD ROOT xxxx True False
# follow follow VERB VB xcomp xxxx True False
# up up PART RP prt xx True False
# from from ADP IN prep xxxx True False
# patient patient ADJ JJ compound xxxx True False
# safety safety NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# for for ADP IN conj xxx True False
# permission permission NOUN NN pobj xxxx True False
# to to PART TO aux xx True False
# contact contact VERB VB acl xxxx True False
# HCP hcp PROPN NNP dobj XXX True False
# . . PUNCT . punct . False False
# SJ sj PROPN NNP ROOT XX True False
# ( ( PUNCT -LRB- punct ( False False
# TMS tms PROPN NNP appos XXX True False
# ) ) PUNCT -RRB- punct ) False False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 2
# XX xx INTJ UH nmod XX True False
# and and CCONJ CC cc xxx True False
# Me -PRON- PRON PRP conj Xx True False
# agent agent NOUN NN nsubj xxxx True False
# called call VERB VBD ROOT xxxx True False
# to to PART TO aux xx True False
# report report VERB VB xcomp xxxx True False
# an an DET DT det xx True False
# adverse adverse ADJ JJ amod xxxx True False
# event event NOUN NN dobj xxxx True False
# on on ADP IN prep xx True False
# behalf behalf NOUN NN pobj xxxx True False
# of of ADP IN prep xx True False
# a a DET DT det x True False
# consumer consumer NOUN NN pobj xxxx True False
# who who NOUN WP nsubj xxx True False
# was be VERB VBD relcl xxx True False
# no no ADV RB neg xx True False
# longer longer ADV RBR advmod xxxx True False
# on on ADP IN prep xx True False
# the the DET DT det xxx True False
# line line NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# consumer consumer NOUN NN nsubj xxxx True False
# began begin VERB VBD ccomp xxxx True False
# Nexium nexium PROPN NNP dobj Xxxxx True False
# 40 40 NUM CD nummod dd False False
# mg mg NOUN NNS npadvmod xx True False
# once once ADV RB advmod xxxx True False
# a a DET DT det x True False
# day day NOUN NN npadvmod xxx True False
# , , PUNCT , punct , False False
# for for ADP IN prep xxx True False
# acid acid ADJ JJ amod xxxx True False
# reflux reflux NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# start start VERB VB compound xxxx True False
# date date NOUN NN nsubj xxxx True False
# not not ADV RB neg xxx True False
# reported report VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# consumer consumer NOUN NN nsubj xxxx True False
# reported report VERB VBD ROOT xxxx True False
# that that ADP IN mark xxxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# acid acid ADJ JJ compound xxxx True False
# reflux reflux NOUN NN nsubj xxxx True False
# was be VERB VBD ccomp xxx True False
# worse bad ADJ JJR acomp xxxx True False
# past past ADJ JJ amod xxxx True False
# couple couple NOUN NN nummod xxxx True False
# days day NOUN NNS npadvmod xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# reported report VERB VBD ccomp xxxx True False
# having have VERB VBG xcomp xxxx True False
# extreme extreme ADJ JJ amod xxxx True False
# stress stress NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# heart heart NOUN NN nsubj xxxx True False
# burn burn VERB VBP ROOT xxxx True False
# and and CCONJ CC cc xxx True False
# is be VERB VBZ aux xx True False
# not not ADV RB neg xxx True False
# eating eat VERB VBG conj xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# consumer consumer NOUN NN nsubj xxxx True False
# further further ADV RB advmod xxxx True False
# clarified clarify VERB VBD ROOT xxxx True False
# that that ADP IN mark xxxx True False
# because because ADP IN prep xxxx True False
# of of ADP IN pcomp xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# acid acid ADJ JJ compound xxxx True False
# reflux reflux NOUN NN nsubj xxxx True False
# getting get VERB VBG pcomp xxxx True False
# worse worse ADV RBR acomp xxxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# doctor doctor NOUN NN nsubj xxxx True False
# increased increase VERB VBD ccomp xxxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# dose dose NOUN NN dobj xxxx True False
# to to ADP IN prep xx True False
# Nexium nexium PROPN NNP pobj Xxxxx True False
# 40 40 NUM CD nummod dd False False
# mg mg NOUN NN npadvmod xx True False
# twice twice ADJ PDT advmod xxxx True False
# a a DET DT det x True False
# day day NOUN NN npadvmod xxx True False
# starting start VERB VBG advcl xxxx True False
# today today NOUN NN npadvmod xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# consumer consumer NOUN NN nsubj xxxx True False
# was be VERB VBD ROOT xxx True False
# no no ADV RB neg xx True False
# longer longer ADV RBR advmod xxxx True False
# on on ADP IN prep xx True False
# the the DET DT det xxx True False
# line line NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# was be VERB VBD conj xxx True False
# unable unable ADJ JJ acomp xxxx True False
# to to PART TO aux xx True False
# provide provide VERB VB xcomp xxxx True False
# additional additional ADJ JJ amod xxxx True False
# information information NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 3
# Patient patient NOUN NN nsubj Xxxxx True False
# advised advise VERB VBD ROOT xxxx True False
# that that ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# had have VERB VBD aux xxx True False
# taken take VERB VBN ccomp xxxx True False
# Nexium nexium PROPN NNP dobj Xxxxx True False
# in in ADP IN prep xx True False
# the the DET DT det xxx True False
# past past NOUN NN pobj xxxx True False
# the the DET DT nsubjpass xxx True False
# was be VERB VBD auxpass xxx True False
# switched switch VERB VBN ccomp xxxx True False
# to to ADP IN prep xx True False
# the the DET DT det xxx True False
# generic generic ADJ JJ pobj xxxx True False
# and and CCONJ CC cc xxx True False
# then then ADV RB advmod xxxx True False
# back back ADV RB conj xxxx True False
# to to ADP IN prep xx True False
# Nexium nexium PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# advised advise VERB VBD ROOT xxxx True False
# that that ADP IN mark xxxx True False
# the the DET DT det xxx True False
# generic generic ADJ JJ nsubj xxxx True False
# does do VERB VBZ aux xxxx True False
# nt not ADV RB advmod xx True False
# work work VERB VB ccomp xxxx True False
# for for ADP IN prep xxx True False
# her -PRON- PRON PRP pobj xxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubj Xxxxx True False
# declined decline VERB VBD ROOT xxxx True False
# to to PART TO aux xx True False
# provide provide VERB VB xcomp xxxx True False
# any any DET DT det xxx True False
# further further ADJ JJ amod xxxx True False
# information information NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 4
# Email email NOUN NN compound Xxxxx True False
# correspondence correspondence NOUN NN ROOT xxxx True False
# received receive VERB VBD acl xxxx True False
# from from ADP IN prep xxxx True False
# XX xx PROPN NNP pobj XX True False
# and and CCONJ CC cc xxx True False
# Me -PRON- PRON PRP conj Xx True False
# . . PUNCT . punct . False False
# Adverse adverse ADJ JJ amod Xxxxx True False
# Event event NOUN NN nsubjpass Xxxxx True False
# was be VERB VBD auxpass xxx True False
# received receive VERB VBN ccomp xxxx True False
# from from ADP IN prep xxxx True False
# XX xx PROPN NNP pobj XX True False
# and and CCONJ CC cc xxx True False
# Me -PRON- PRON PRP conj Xx True False
# by by ADP IN agent xx True False
# email email NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# as as ADP IN mark xx True False
# they -PRON- PRON PRP nsubj xxxx True False
# were be VERB VBD advcl xxxx True False
# unable unable ADJ JJ acomp xxxx True False
# to to PART TO aux xx True False
# contact contact VERB VB xcomp xxxx True False
# the the DET DT det xxx True False
# IC ic PROPN NNP dobj XX True False
# by by ADP IN prep xx True False
# phone phone NOUN NN pobj xxxx True False
# , , PUNCT , punct , False False
# no no DET DT det xx True False
# attachments attachment NOUN NNS nsubjpass xxxx True False
# are be VERB VBP auxpass xxx True False
# associated associate VERB VBN ROOT xxxx True False
# with with ADP IN prep xxxx True False
# this this DET DT det xxxx True False
# case case NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Subject subject NOUN NN ROOT Xxxxx True False
# This this DET DT nsubj Xxxx True False
# is be VERB VBZ ROOT xx True False
# a a DET DT det x True False
# possible possible ADJ JJ amod xxxx True False
# AE ae NOUN NN attr XX True False
# , , PUNCT , punct , False False
# PQC pqc PROPN NNP conj XXX True False
# , , PUNCT , punct , False False
# or or CCONJ CC cc xx True False
# Medical medical PROPN NNP nmod Xxxxx True False
# / / SYM SYM punct / False False
# Product product PROPN NNP compound Xxxxx True False
# Inquiry inquiry PROPN NNP conj Xxxxx True False
# from from ADP IN prep xxxx True False
# XXandMe xxandme PROPN NNP compound XXxxxXx True False
# inVentiv inventiv PROPN NNP pobj xxXxxxx True False
# . . PUNCT . punct . False False
# Please please INTJ UH intj Xxxxx True False
# treat treat VERB VB ROOT xxxx True False
# this this DET DT dobj xxxx True False
# as as ADP IN prep xx True False
# an an DET DT det xx True False
# urgent urgent ADJ JJ amod xxxx True False
# case case NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# AE ae PROPN NNP nsubj XX True False
# received receive VERB VBN ROOT xxxx True False
# by by ADP IN prep xx True False
# phone phone NOUN NN pobj xxxx True False
# on on ADP IN prep xx True False
# 21 21 NUM CD nummod dd False False
# - - SYM SYM punct - False False
# 09 09 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 2015 2015 NUM CD pobj dddd False False
# . . PUNCT . punct . False False
# Information information NOUN NN nsubjpass Xxxxx True False
# that that ADJ WDT nsubj xxxx True False
# includes include VERB VBZ relcl xxxx True False
# the the DET DT det xxx True False
# PERD perd PROPN NNP compound XXXX True False
# requirements requirement NOUN NNS dobj xxxx True False
# or or CCONJ CC cc xx True False
# PQC pqc PROPN NNP compound XXX True False
# requirements requirement NOUN NNS conj xxxx True False
# is be VERB VBZ auxpass xx True False
# provided provide VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
# Text text PROPN NNP compound Xxxx True False
# Body body PROPN NNP ROOT Xxxx True False
# Date:21 date:21 PROPN NNP npadvmod Xxxx:dd False False
# - - PUNCT HYPH punct - False False
# 09 09 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 2015 2015 NUM CD nummod dddd False False
# How how ADV WRB advmod Xxx True False
# was be VERB VBD auxpass xxx True False
# it -PRON- PRON PRP nsubjpass xx True False
# received receive VERB VBN ROOT xxxx True False
# : : PUNCT : punct : False False
# PHONE phone NOUN NN compound XXXX True False
# Time time NOUN NN ROOT Xxxx True False
# reported:2:50 reported:2:50 PROPN NNP compound xxxx:d:dd False False
# p.m. p.m. NOUN NN appos x.x. False False
# Patient patient ADJ JJ compound Xxxxx True False
# information information NOUN NN ROOT xxxx True False
# : : PUNCT : punct : False False
# Pamela pamela PROPN NNP compound Xxxxx True False
# Desjardins desjardins PROPN NNP appos Xxxxx True False
# , , PUNCT , punct , False False
# XX xx PROPN NNP appos XX True False
# , , PUNCT , punct , False False
# , , PUNCT , punct , False False
# xxx.xx.0246(DIS xxx.xx.0246(dis PROPN NNP appos xxx.xx.dddd(XXX False False
# removed remove VERB VBN amod xxxx True False
# numbers number NOUN NNS appos xxxx True False
# from from ADP IN prep xxxx True False
# Social social PROPN NNP compound Xxxxx True False
# Security security PROPN NNP compound Xxxxx True False
# number number NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# replaced replace VERB VBN conj xxxx True False
# with with ADP IN prep xxxx True False
# xxx xxx NOUN NN pobj xxx True False
# for for ADP IN prep xxx True False
# privacy privacy NOUN NN pobj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# Event event NOUN NN dep Xxxxx True False
# : : PUNCT : punct : False False
# Pt pt PROPN NNP nsubj Xx True False
# has have VERB VBZ aux xxx True False
# missed miss VERB VBN ROOT xxxx True False
# 2 2 NUM CD nummod d False False
# days day NOUN NNS dobj xxxx True False
# of of ADP IN prep xx True False
# meds med NOUN NNS compound xxxx True False
# Reporter reporter NOUN NN pobj Xxxxx True False
# : : PUNCT . punct : False False
# Pamela pamela PROPN NNP compound Xxxxx True False
# Desjardins desjardins PROPN NNP compound Xxxxx True False
# Drug drug PROPN NNP ROOT Xxxx True False
# : : PUNCT : punct : False False
# Seroquel seroquel PROPN NNP appos Xxxxx True False
# XR xr PROPN NNP appos XX True False
# 400 400 NUM CD nummod ddd False False
# mg mg ADP IN compound xx True False
# tab tab NOUN NN appos xxx True False
# No no DET DT det Xx True False
# other other ADJ JJ amod xxxx True False
# information information NOUN NN nsubj xxxx True False
# provided provide VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
# No no DET DT det Xx True False
# permission permission NOUN NN nsubj xxxx True False
# provided provide VERB VBN acl xxxx True False
# for for ADP IN prep xxx True False
# Patient patient PROPN NNP compound Xxxxx True False
# Safety safety PROPN NNP pobj Xxxxx True False
# to to PART TO aux xx True False
# recontact recontact VERB VB acl xxxx True False
# Reporter reporter NOUN NN dobj Xxxxx True False
# or or CCONJ CC cc xx True False
# to to PART TO aux xx True False
# contact contact VERB VB conj xxxx True False
# HCP.JN(TMS hcp.jn(tms PROPN NNP dobj XXX.XX(XXX False False
# ) ) PUNCT -RRB- punct ) False False
# Follow follow VERB VB ROOT Xxxxx True False
# up up PART RP prt xx True False
# received receive VERB VBN xcomp xxxx True False
# on on ADP IN prep xx True False
# 04 04 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 12 12 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 2017 2017 NUM CD pobj dddd False False
# . . PUNCT . punct . False False
# Enrolled enrol VERB VBN amod Xxxxx True False
# patient patient NOUN NN nsubj xxxx True False
# transferred transfer VERB VBN ROOT xxxx True False
# from from ADP IN prep xxxx True False
# XX xx PROPN NNP pobj XX True False
# and and CCONJ CC cc xxx True False
# Me -PRON- PRON PRP conj Xx True False
# . . PUNCT . punct . False False
# 2 2 NUM CD quantmod d False False
# to to ADP IN quantmod xx True False
# 3 3 NUM CD nummod d False False
# years year NOUN NNS npadvmod xxxx True False
# ago ago ADV RB advmod xxx True False
# she -PRON- PRON PRP nsubj xxx True False
# did do VERB VBD aux xxx True False
# not not ADV RB neg xxx True False
# do do VERB VB ROOT xx True False
# well well ADV RB advmod xxxx True False
# on on ADP IN prep xx True False
# the the DET DT det xxx True False
# generic generic ADJ JJ amod xxxx True False
# Seroquel seroquel PROPN NNP compound Xxxxx True False
# XR xr PROPN NNP pobj XX True False
# , , PUNCT , punct , False False
# exact exact ADJ JJ amod xxxx True False
# date date NOUN NN npadvmod xxxx True False
# unknown unknown ADJ JJ advcl xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# clarified clarify VERB VBD ROOT xxxx True False
# by by ADP IN prep xx True False
# stating state VERB VBG pcomp xxxx True False
# that that ADP IN mark xxxx True False
# while while ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# was be VERB VBD aux xxx True False
# using use VERB VBG advcl xxxx True False
# the the DET DT det xxx True False
# generic generic ADJ JJ dobj xxxx True False
# for for ADP IN prep xxx True False
# 30 30 NUM CD nummod dd False False
# days day NOUN NNS pobj xxxx True False
# , , PUNCT , punct , False False
# she -PRON- PRON PRP nsubj xxx True False
# did do VERB VBD aux xxx True False
# not not ADV RB neg xxx True False
# sleep sleep VERB VB ccomp xxxx True False
# well well ADV RB advmod xxxx True False
# and and CCONJ CC cc xxx True False
# was be VERB VBD conj xxx True False
# shaky shaky ADJ JJ acomp xxxx True False
# . . PUNCT . punct . False False
# Her -PRON- ADJ PRP$ poss Xxx True False
# HCP hcp PROPN NNP nsubj XXX True False
# was be VERB VBD ROOT xxx True False
# aware aware ADJ JJ acomp xxxx True False
# and and CCONJ CC cc xxx True False
# switched switch VERB VBD conj xxxx True False
# her -PRON- PRON PRP dobj xxx True False
# back back ADV RB advmod xxxx True False
# to to ADP IN prep xx True False
# Seroquel seroquel PROPN NNP compound Xxxxx True False
# XR xr PROPN NNP compound XX True False
# brand brand NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# those those DET DT det xxxx True False
# symptoms symptom NOUN NNS nsubj xxxx True False
# resolved resolve VERB VBN conj xxxx True False
# . . PUNCT . punct . False False
# Her -PRON- ADJ PRP$ poss Xxx True False
# pharmacist pharmacist NOUN NN nsubj xxxx True False
# told tell VERB VBD ROOT xxxx True False
# her -PRON- PRON PRP dobj xxx True False
# it -PRON- PRON PRP nsubj xx True False
# may may VERB MD aux xxx True False
# have have VERB VB aux xxxx True False
# been be VERB VBN ccomp xxxx True False
# due due ADJ JJ acomp xxx True False
# to to ADP IN pcomp xx True False
# the the DET DT det xxx True False
# fillers filler NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# PS ps PROPN NNP nsubj XX True False
# granted grant VERB VBD ROOT xxxx True False
# permission permission NOUN NN dobj xxxx True False
# to to PART TO aux xx True False
# contact contact VERB VB advcl xxxx True False
# patient patient ADJ JJ dobj xxxx True False
# . . PUNCT . punct . False False
# Her -PRON- ADJ PRP$ poss Xxx True False
# address address NOUN NN nsubj xxxx True False
# is be VERB VBZ ccomp xx True False
# as as ADP IN mark xx True False
# stated state VERB VBN advcl xxxx True False
# above above ADV RB advmod xxxx True False
# , , PUNCT , punct , False False
# her -PRON- ADJ PRP$ poss xxx True False
# email email NOUN NN nsubj xxxx True False
# is be VERB VBZ ROOT xx True False
# xxx@yahoo.com xxx@yahoo.com X ADD attr xxx@xxxx.xxx False False
# , , PUNCT , punct , False False
# and and CCONJ CC cc xxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# phone phone NOUN NN compound xxxx True False
# number number NOUN NN nsubj xxxx True False
# is be VERB VBZ conj xx True False
# 480.300.9210 480.300.9210 NUM CD attr ddd.ddd.dddd False False
# . . PUNCT . punct . False False
# PS ps PROPN NNP nsubj XX True False
# also also ADV RB advmod xxxx True False
# has have VERB VBZ ROOT xxx True False
# permission permission NOUN NN dobj xxxx True False
# to to PART TO aux xx True False
# contact contact VERB VB acl xxxx True False
# her -PRON- ADJ PRP$ dobj xxx True False
# HCP hcp PROPN NNP compound XXX True False
# Dr. dr. PROPN NNP compound Xx. False False
# Michael michael PROPN NNP compound Xxxxx True False
# Mar mar PROPN NNP compound Xxx True False
# practicing practice VERB VBG dobj xxxx True False
# . . PUNCT . punct . False False
# No no DET DT det Xx True False
# further further ADJ JJ amod xxxx True False
# information information NOUN NN ROOT xxxx True False
# provided provide VERB VBN acl xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 5
# The the DET DT det Xxx True False
# patients patient NOUN NNS nsubj xxxx True False
# daughter daughter NOUN NN appos xxxx True False
# reports report VERB VBZ ROOT xxxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# mother mother NOUN NN nsubj xxxx True False
# has have VERB VBZ aux xxx True False
# been be VERB VBN aux xxxx True False
# having have VERB VBG ccomp xxxx True False
# " " PUNCT `` punct " False False
# abdominal abdominal ADJ JJ amod xxxx True False
# burning burn VERB VBG amod xxxx True False
# pains pain NOUN NNS dobj xxxx True False
# " " PUNCT '' punct " False False
# since since ADP IN prep xxxx True False
# starting start VERB VBG pcomp xxxx True False
# the the DET DT det xxx True False
# Lynparza lynparza PROPN NNP dobj Xxxxx True False
# . . PUNCT . punct . False False
# Patient patient NOUN NN nsubj Xxxxx True False
# had have VERB VBD ROOT xxx True False
# labs lab NOUN NNS dobj xxxx True False
# drawn draw VERB VBN acl xxxx True False
# and and CCONJ CC cc xxx True False
# saw see VERB VBD conj xxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# oncologist oncologist NOUN NN dobj xxxx True False
# yesterday yesterday NOUN NN npadvmod xxxx True False
# and and CCONJ CC cc xxx True False
# informed inform VERB VBD conj xxxx True False
# him -PRON- PRON PRP dobj xxx True False
# of of ADP IN prep xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# symptoms symptom NOUN NNS pobj xxxx True False
# . . PUNCT . punct . False False
# Her -PRON- ADJ PRP$ poss Xxx True False
# labs lab NOUN NNS nsubj xxxx True False
# were be VERB VBD ROOT xxxx True False
# all all ADV RB advmod xxx True False
# okay okay ADJ JJ acomp xxxx True False
# and and CCONJ CC cc xxx True False
# the the DET DT det xxx True False
# oncologist oncologist NOUN NN nsubj xxxx True False
# examined examine VERB VBD conj xxxx True False
# the the DET DT det xxx True False
# patient patient NOUN NN dobj xxxx True False
# but but CCONJ CC cc xxx True False
# did do VERB VBD aux xxx True False
# not not ADV RB neg xxx True False
# give give VERB VB conj xxxx True False
# her -PRON- ADJ PRP$ dative xxx True False
# anything anything NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# stomach stomach NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 6
# Patients patient NOUN NNS compound Xxxxx True False
# husband husband NOUN NN nsubj xxxx True False
# reported report VERB VBD ROOT xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# has have VERB VBZ ccomp xxx True False
# nausea nausea NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# vomiting vomiting NOUN NN advcl xxxx True False
# , , PUNCT , punct , False False
# " " PUNCT `` punct " False False
# ca can VERB MD aux xx True False
# nt not ADV RB advmod xx True False
# eat eat VERB VB conj xxx True False
# " " PUNCT '' punct " False False
# and and CCONJ CC cc xxx True False
# is be VERB VBZ conj xx True False
# unable unable ADJ JJ acomp xxxx True False
# to to PART TO aux xx True False
# sleep sleep VERB VB xcomp xxxx True False
# . . PUNCT . punct . False False
# He -PRON- PRON PRP nsubj Xx True False
# reports report VERB VBZ ROOT xxxx True False
# that that ADP IN mark xxxx True False
# patients patient NOUN NNS compound xxxx True False
# labs lab NOUN NNS nsubj xxxx True False
# have have VERB VBP aux xxxx True False
# been be VERB VBN ccomp xxxx True False
# okay okay ADJ JJ acomp xxxx True False
# but but CCONJ CC cc xxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# RBCs rbc NOUN NNS nsubj XXXx True False
# are be VERB VBP conj xxx True False
# slightly slightly ADV RB advmod xxxx True False
# low low ADJ JJ acomp xxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False
# Paragraph number... 7
# One one NUM CD nummod Xxx True False
# 25 25 NUM CD nummod dd False False
# years year NOUN NNS npadvmod xxxx True False
# old old ADJ JJ amod xxx True False
# female female ADJ JJ amod xxxx True False
# patient patient NOUN NN nsubj xxxx True False
# received receive VERB VBN ROOT xxxx True False
# Symbicort symbicort PROPN NNP dative Xxxxx True False
# 160 160 NUM CD nummod ddd False False
# ug ug PROPN NNP nsubj xx True False
# bid bid NOUN NN advcl xxx True False
# for for ADP IN prep xxx True False
# asthma asthma NOUN NN pobj xxxx True False
# via via ADP IN prep xxx True False
# prescription prescription NOUN NN pobj xxxx True False
# since since ADP IN prep xxxx True False
# over over ADP IN quantmod xxxx True False
# one one NUM CD nummod xxx True False
# month month NOUN NN npadvmod xxxx True False
# ago ago ADV RB pcomp xxx True False
# . . PUNCT . punct . False False
# No no DET DT det Xx True False
# other other ADJ JJ amod xxxx True False
# medical medical ADJ JJ amod xxxx True False
# history history NOUN NN ROOT xxxx True False
# . . PUNCT . punct . False False
# One one NUM CD nummod Xxx True False
# week week NOUN NN npadvmod xxxx True False
# after after ADP IN prep xxxx True False
# medication medication NOUN NN pobj xxxx True False
# her -PRON- ADJ PRP$ poss xxx True False
# face face NOUN NN nsubj xxxx True False
# appeared appear VERB VBD ROOT xxxx True False
# rash rash ADJ JJ oprd xxxx True False
# vesicular(little vesicular(little NOUN NN amod xxxx(xxxx False False
# blisters blister NOUN NNS dobj xxxx True False
# accompanying accompany VERB VBG acl xxxx True False
# with with ADP IN prep xxxx True False
# pain pain NOUN NN pobj xxxx True False
# ) ) PUNCT -RRB- punct ) False False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# visited visit VERB VBD ccomp xxxx True False
# pneumology pneumology NOUN NN compound xxxx True False
# department department NOUN NN dobj xxxx True False
# , , PUNCT , punct , False False
# the the DET DT det xxx True False
# doctor doctor NOUN NN nsubj xxxx True False
# said say VERB VBD ROOT xxxx True False
# allergic allergic ADJ JJ amod xxxx True False
# symptom symptom NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True False
# Symbicort symbicort PROPN NNP pobj Xxxxx True False
# was be VERB VBD auxpass xxx True False
# rare rare ADJ JJ acomp xxxx True False
# , , PUNCT , punct , False False
# it -PRON- PRON PRP nsubjpass xx True False
# was be VERB VBD auxpass xxx True False
# uncertainly uncertainly ADV RB advmod xxxx True False
# caused cause VERB VBN ccomp xxxx True False
# by by ADP IN agent xx True False
# Symbicort symbicort PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# Dermatologist dermatologist NOUN NN nsubj Xxxxx True False
# said say VERB VBD ROOT xxxx True False
# it -PRON- PRON PRP nsubjpass xx True False
# might may VERB MD aux xxxx True False
# be be VERB VB auxpass xx True False
# caused cause VERB VBN ccomp xxxx True False
# by by ADP IN agent xx True False
# hormone hormone NOUN NN compound xxxx True False
# ingredient ingredient NOUN NN pobj xxxx True False
# of of ADP IN prep xx True False
# Symbicort symbicort PROPN NNP pobj Xxxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# smeared smear VERB VBD ROOT xxxx True False
# Ganciclovir ganciclovir PROPN NNP compound Xxxxx True False
# Gel gel PROPN NNP dobj Xxx True False
# and and CCONJ CC cc xxx True False
# then then ADV RB advmod xxxx True False
# the the DET DT det xxx True False
# AE ae PROPN NNP nsubjpass XX True False
# was be VERB VBD auxpass xxx True False
# improved improve VERB VBN conj xxxx True False
# . . PUNCT . punct . False False
# But but CCONJ CC cc Xxx True False
# rash rash ADJ JJ compound xxxx True False
# vesicular vesicular NOUN NN nsubj xxxx True False
# would would VERB MD aux xxxx True False
# recur recur VERB VB ROOT xxxx True False
# when when ADV WRB advmod xxxx True False
# Symbicort symbicort PROPN NNP nsubjpass Xxxxx True False
# was be VERB VBD auxpass xxx True False
# received receive VERB VBN advcl xxxx True False
# . . PUNCT . punct . False False
# Fu fu PROPN NNP dep Xx True False
# on on ADP IN prep xx True False
# 12 12 NUM CD nummod dd False False
# - - SYM SYM punct - False False
# 12 12 NUM CD nummod dd False False
# - - PUNCT HYPH punct - False False
# 2017 2017 NUM CD pobj dddd False False
# : : PUNCT : punct : False False
# This this DET DT nsubj Xxxx True False
# is be VERB VBZ ROOT xx True False
# a a DET DT det x True False
# follow follow NOUN NN attr xxxx True False
# up up PART RP prt xx True False
# spontaneous spontaneous ADJ JJ amod xxxx True False
# report report NOUN NN dobj xxxx True False
# concerning concern VERB VBG acl xxxx True False
# a a DET DT det x True False
# female female ADJ JJ amod xxxx True False
# patient patient NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# Concomitant concomitant ADJ JJ amod Xxxxx True False
# medication medication NOUN NN nsubjpass xxxx True False
# was be VERB VBD auxpass xxx True False
# not not ADV RB neg xxx True False
# reported report VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# patient patient NOUN NN nsubj xxxx True False
# received receive VERB VBD ROOT xxxx True False
# Symbicort symbicort PROPN NNP dobj Xxxxx True False
# for for ADP IN prep xxx True False
# asthma asthma NOUN NN pobj xxxx True False
# via via ADP IN prep xxx True False
# prescription prescription NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# visited visit VERB VBD ROOT xxxx True False
# a a DET DT det x True False
# doctor doctor NOUN NN dobj xxxx True False
# for for ADP IN prep xxx True False
# examination examination NOUN NN pobj xxxx True False
# on on ADP IN prep xx True False
# an an DET DT det xx True False
# unspecified unspecified ADJ JJ amod xxxx True False
# date date NOUN NN pobj xxxx True False
# after after ADP IN mark xxxx True False
# she -PRON- PRON PRP nsubj xxx True False
# received receive VERB VBD advcl xxxx True False
# Symbicort symbicort PROPN NNP dobj Xxxxx True False
# for for ADP IN prep xxx True False
# a a DET DT det x True False
# period period NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# The the DET DT det Xxx True False
# result result NOUN NN nsubj xxxx True False
# of of ADP IN prep xx True False
# tracheoscopy tracheoscopy NOUN NN compound xxxx True False
# examination examination NOUN NN pobj xxxx True False
# showed show VERB VBD ROOT xxxx True False
# that that ADP IN mark xxxx True False
# there there ADV EX expl xxxx True False
# was be VERB VBD ccomp xxx True False
# candida candida NOUN NN compound xxxx True False
# albicans albican NOUN NNS compound xxxx True False
# infection infection NOUN NN attr xxxx True False
# in in ADP IN prep xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# lung lung NOUN NN pobj xxxx True False
# and and CCONJ CC cc xxx True False
# the the DET DT det xxx True False
# result result NOUN NN conj xxxx True False
# of of ADP IN prep xx True False
# sputum sputum NOUN NN compound xxxx True False
# examination examination NOUN NN pobj xxxx True False
# showed show VERB VBD ccomp xxxx True False
# that that ADP IN mark xxxx True False
# there there ADV EX expl xxxx True False
# was be VERB VBD ccomp xxx True False
# monilial monilial ADJ JJ amod xxxx True False
# infection infection NOUN NN attr xxxx True False
# in in ADP IN prep xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# oropharynx oropharynx NOUN NN pobj xxxx True False
# . . PUNCT . punct . False False
# She -PRON- PRON PRP nsubj Xxx True False
# visited visit VERB VBD ROOT xxxx True False
# a a DET DT det x True False
# doctor doctor NOUN NN dobj xxxx True False
# and and CCONJ CC cc xxx True False
# the the DET DT det xxx True False
# doctor doctor NOUN NN nsubj xxxx True False
# did do VERB VBD aux xxx True False
# nt not ADV RB advmod xx True False
# give give VERB VB conj xxxx True False
# the the DET DT det xxx True False
# treatment treatment NOUN NN dobj xxxx True False
# . . PUNCT . punct . False False
# Information information NOUN NN nsubjpass Xxxxx True False
# concerning concern VERB VBG acl xxxx True False
# new new ADJ JJ amod xxx True False
# AEs ae NOUN NNS dobj XXx True False
# of of ADP IN prep xx True False
# ’candida ’candida PROPN NNP compound ’xxxx False False
# albicans albican NOUN NNS compound xxxx True False
# infection infection NOUN NN pobj xxxx True False
# in in ADP IN prep xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# lung lung NOUN NN nmod xxxx True False
# and and CCONJ CC cc xxx True False
# ’monilial ’monilial ADJ JJ conj ’xxxx False False
# infection infection NOUN NN pobj xxxx True False
# in in ADP IN prep xx True False
# her -PRON- ADJ PRP$ poss xxx True False
# oropharynx oropharynx NOUN NN pobj xxxx True False
# was be VERB VBD auxpass xxx True False
# added add VERB VBN ROOT xxxx True False
# . . PUNCT . punct . False False
#
#
#  SPACE
#  False False

# %% [markdown]
# ### Named Entities

# %% [markdown]
# A named entity is a "real-world object" that's assigned a name – for example, a person, a country, a product or a book title. spaCy can recognise various types of named entities in a document, by asking the model for a prediction. Because models are statistical and strongly depend on the examples they were trained on, this doesn't always work perfectly and might need some tuning later, depending on your use case.
#
# Named entities are available as the ents property of a Doc:

# %%
for i in range(len(patient)):
    print("Paragraph number...", i)
    doc = nlp(patient[i])
    for ent in doc.ents:
        print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Paragraph number... 0
# IC 26 28 ORG
# Crestor 77 84 ORG
# Patient 86 93 ORG
# Crestor 102 109 ORG
# 10 mg 110 115 CARDINAL
# daily 116 121 DATE
# 01-2008 134 141 DATE
# Patient 164 171 ORG
# Toprol XL 184 193 ORG
# daily 200 205 DATE
# 11-2000 226 233 DATE
# Crestor 320 327 ORG
# the years 333 342 DATE
# 12-2017 396 403 DATE
# the next day 440 452 DATE
# HCP 497 500 ORG
# about 2003 560 570 DATE
# Crestor 598 605 PRODUCT
# HCP 686 689 ORG
# Crestor 725 732 PRODUCT
# Crestor 755 762 PRODUCT
# 03-01-2018 823 833 DATE
# 03-01-2018 846 856 DATE
# Patient 922 929 ORG
# Crestor 969 976 PRODUCT
# Paragraph number... 1
# XX 23 25 PERSON
# UNK 183 186 ORG
# HCP 794 797 ORG
# SJ 799 801 ORG
# Paragraph number... 2
# XX 0 2 PERSON
# Nexium 124 130 ORG
# couple days 249 260 DATE
# today 472 477 DATE
# Paragraph number... 3
# Nexium 103 109 ORG
# Patient 161 168 ORG
# Paragraph number... 4
# XX 35 37 PERSON
# XX 78 80 PERSON
# AE 219 221 ORG
# PQC 223 226 ORG
# Medical/Product Inquiry 231 254 ORG
# XXandMe inVentiv 260 276 PERSON
# AE 315 317 ORG
# 21-09-2015 339 349 DATE
# PERD 381 385 ORG
# Text Body 432 441 PRODUCT
# Date:21-09-2015 442 457 DATE
# PHONE Time reported:2:50 p.m. 478 507 PERSON
# Pamela Desjardins 528 545 PERSON
# XX 546 548 PERSON
# xxx.xx.0246(DIS 552 567 ORG
# Social Security 589 604 ORG
# 2 days 667 673 DATE
# Pamela Desjardins Drug 691 713 PERSON
# Seroquel XR 714 725 ORG
# 400 726 729 PRODUCT
# Patient Safety 795 809 ORG
# HCP.JN(TMS 846 856 PERSON
# 04-12-2017 880 890 DATE
# XX 926 928 PERSON
# 2 to 3 years ago 937 953 DATE
# Seroquel XR 989 1000 ORG
# 30 days 1088 1095 DATE
# HCP 1139 1142 ORG
# Seroquel XR 1178 1189 ORG
# 480.300.9210 1413 1425 CARDINAL
# HCP 1465 1468 ORG
# Michael Mar 1473 1484 PERSON
# Paragraph number... 5
# Lynparza 102 110 PERSON
# yesterday 158 167 DATE
# Paragraph number... 6
# Paragraph number... 7
# One 25 years old 0 16 DATE
# Symbicort 41 50 ORG
# 160 51 54 CARDINAL
# over one month ago 96 114 DATE
# One week 142 150 DATE
# Symbicort 313 322 ORG
# Symbicort 362 371 ORG
# Symbicort 436 445 ORG
# Ganciclovir Gel 459 474 ORG
# AE 488 490 ORG
# Symbicort 541 550 ORG
# 12 571 573 CARDINAL
# Symbicort 713 722 ORG
# an unspecified date 792 811 DATE
# Symbicort 831 840 ORG

# %% [markdown]
# ### Word vectors and similarity measures

# %%
tokens = nlp(u'dog cat banana')
for token1 in tokens:
    for token2 in tokens:
        print(token1.text, token2.text, token1.similarity(token2))
# Out:
# dog dog 1.0
# dog cat 0.80168545
# dog banana 0.24327643
# cat dog 0.80168545
# cat cat 1.0
# cat banana 0.28154364
# banana dog 0.24327643
# banana cat 0.28154364
# banana banana 1.0

# %% [markdown]
# n this case, the model's predictions are pretty on point. A dog is very similar to a cat, whereas a banana is not very similar to either of them. Identical tokens are obviously 100% similar to each other (just not always exactly 1.0, because of vector math and floating point imprecisions).
#
# Similarity is determined by comparing word vectors or "word embeddings", multi-dimensional meaning representations of a word. Word vectors can be generated using an algorithm like word2vec and usually look like this:

# %% [markdown]
# ### Vocab, Hashes and Lexemes

# %% [markdown]
# Whenever possible, spaCy tries to store data in a vocabulary, the Vocab , that will be shared by multiple documents. To save memory, spaCy also encodes all strings to hash values – in this case for example, "coffee" has the hash 3197928453018144401. Entity labels like "ORG" and part-of-speech tags like "VERB" are also encoded. Internally, spaCy only "speaks" in hash values.

# %% [markdown]
# If you process lots of documents containing the word "coffee" in all kinds of different contexts, storing the exact string "coffee" every time would take up way too much space. So instead, spaCy hashes the string and stores it in the StringStore . You can think of the StringStore as a lookup table that works in both directions – you can look up a string to get its hash, or a hash to get its string:

# %%
doc = nlp(u'I love coffee')
print(doc.vocab.strings[u'coffee'])  # 3197928453018144401
print(doc.vocab.strings[3197928453018144401])  # 'coffee'
# Out:
# 3197928453018144401
# coffee

# %% [markdown]
# Now that all strings are encoded, the entries in the vocabulary don't need to include the word text themselves. Instead, they can look it up in the StringStore via its hash value. Each entry in the vocabulary, also called Lexeme , contains the context-independent information about a word. For example, no matter if "love" is used as a verb or a noun in some context, its spelling and whether it consists of alphabetic characters won't ever change. Its hash value will also always be the same.

# %%
for i in range(len(patient)):
    print("Paragraph number...", i)
    doc = nlp(patient[i])
    for word in doc:
        lexeme = doc.vocab[word.text]
        print(lexeme.text, lexeme.orth, lexeme.shape_, lexeme.prefix_, lexeme.suffix_,
          lexeme.is_alpha, lexeme.is_digit, lexeme.is_title, lexeme.lang_)
# Out:
# Paragraph number... 0
# Call 11104957948539619373 Xxxx C all True False True en
# came 15989513710403574752 xxxx c ame True False False en
# directly 9431896469908734155 xxxx d tly True False False en
# to 3791531372978436496 xx t to True False False en
# the 7425985699627899538 xxx t the True False False en
# IC 9397940574446756610 XX I IC True False False en
# for 16037325823156266367 xxx f for True False False en
# medical 10039723232229819975 xxxx m cal True False False en
# inquiry 14225684692882789161 xxxx i iry True False False en
# and 2283656566040971221 xxx a and True False False en
# adverse 10274160298693536259 xxxx a rse True False False en
# event 16065740214838660377 xxxx e ent True False False en
# noted 6777982591128005566 xxxx n ted True False False en
# for 16037325823156266367 xxx f for True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# started 17976686883172633439 xxxx s ted True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# 10 6572986864102252890 dd 1 10 False True False en
# mg 722646293792979593 xx m mg True False False en
# daily 7369875328865446693 xxxx d ily True False False en
# by 16764210730586636600 xx b by True False False en
# mouth 16921435939284083306 xxxx m uth True False False en
# in 3002984154512732771 xx i in True False False en
# 01 2577082955473810581 dd 0 01 False True False en
# - 9153284864653046197 - - - False False False en
# 2008 15389013775748810664 dddd 2 008 False True False en
# for 16037325823156266367 xxx f for True False False en
# high 8587113882175654237 xxxx h igh True False False en
# cholesterol 5358441682275759386 xxxx c rol True False False en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# also 12084876542534825196 xxxx a lso True False False en
# taking 4637778817647943105 xxxx t ing True False False en
# Toprol 4020629293559048325 Xxxxx T rol True False True en
# XL 267949300442822177 XX X XL True False False en
# 50 16774477578904899363 dd 5 50 False True False en
# mg 722646293792979593 xx m mg True False False en
# daily 7369875328865446693 xxxx d ily True False False en
# by 16764210730586636600 xx b by True False False en
# mouth 16921435939284083306 xxxx m uth True False False en
# started 17976686883172633439 xxxx s ted True False False en
# in 3002984154512732771 xx i in True False False en
# 11 2988402087957123519 dd 1 11 False True False en
# - 9153284864653046197 - - - False False False en
# 2000 13316954075855326846 dddd 2 000 False True False en
# for 16037325823156266367 xxx f for True False False en
# high 8587113882175654237 xxxx h igh True False False en
# blood 2077320337565082816 xxxx b ood True False False en
# pressure 17263923162380449268 xxxx p ure True False False en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# reported 11181246799942687462 xxxx r ted True False False en
# the 7425985699627899538 xxx t the True False False en
# following 7893390400297566341 xxxx f ing True False False en
# that 4380130941430378203 xxxx t hat True False False en
# she 6740321247510922449 xxx s she True False False en
# has 1248239241591158246 xxx h has True False False en
# skipped 16961366473853865959 xxxx s ped True False False en
# doses 10718517124751874050 xxxx d ses True False False en
# of 886050111519832510 xx o of True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# over 5456543204961066030 xxxx o ver True False False en
# the 7425985699627899538 xxx t the True False False en
# years 9492612516460955585 xxxx y ars True False False en
# since 10066841407251338481 xxxx s nce True False False en
# she 6740321247510922449 xxx s she True False False en
# started 17976686883172633439 xxxx s ted True False False en
# taking 4637778817647943105 xxxx t ing True False False en
# it 10239237003504588839 xx i it True False False en
# and 2283656566040971221 xxx a and True False False en
# the 7425985699627899538 xxx t the True False False en
# last 10321518907502812892 xxxx l ast True False False en
# time 8885804376230376864 xxxx t ime True False False en
# was 9921686513378912864 xxx w was True False False en
# in 3002984154512732771 xx i in True False False en
# 12 1124146173557384544 dd 1 12 False True False en
# - 9153284864653046197 - - - False False False en
# 2017 12587536829529815270 dddd 2 017 False True False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# would 6992604926141104606 xxxx w uld True False False en
# just 7148522813498185515 xxxx j ust True False False en
# take 6789454535283781228 xxxx t ake True False False en
# her 4115755726172261197 xxx h her True False False en
# usual 8736397080351936157 xxxx u ual True False False en
# dose 3913336927868767965 xxxx d ose True False False en
# the 7425985699627899538 xxx t the True False False en
# next 5589923990388768802 xxxx n ext True False False en
# day 1608482186128794349 xxx d day True False False en
# and 2283656566040971221 xxx a and True False False en
# not 447765159362469301 xxx n not True False False en
# try 4812066089261065646 xxx t try True False False en
# to 3791531372978436496 xx t to True False False en
# make 9614445426764226664 xxxx m ake True False False en
# up 2199259611705938403 xx u up True False False en
# the 7425985699627899538 xxx t the True False False en
# missed 18163165972514536835 xxxx m sed True False False en
# dose 3913336927868767965 xxxx d ose True False False en
# . 12646065887601541794 . . . False False False en
# Her 452811260292132302 Xxx H Her True False True en
# HCP 2183834458705439728 XXX H HCP True False False en
# is 3411606890003347522 xx i is True False False en
# aware 15981128065641363532 xxxx a are True False False en
# , 2593208677638477497 , , , False False False en
# no 13055779130471031426 xx n no True False False en
# treatment 17998780750743588112 xxxx t ent True False False en
# offered 17189094373072717712 xxxx o red True False False en
# . 12646065887601541794 . . . False False False en
# Had 6865576549405853585 Xxx H Had True False True en
# high 8587113882175654237 xxxx h igh True False False en
# cholesterol 5358441682275759386 xxxx c rol True False False en
# since 10066841407251338481 xxxx s nce True False False en
# about 942632335873952620 xxxx a out True False False en
# 2003 8432622206782721414 dddd 2 003 False True False en
# and 2283656566040971221 xxx a and True False False en
# currently 9613471778328020307 xxxx c tly True False False en
# taking 4637778817647943105 xxxx t ing True False False en
# brand 3827899546313821993 xxxx b and True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# is 3411606890003347522 xx i is True False False en
# nervous 11216294436333666104 xxxx n ous True False False en
# now 17157488710739566268 xxx n now True False False en
# about 942632335873952620 xxxx a out True False False en
# taking 4637778817647943105 xxxx t ing True False False en
# new 4753564829687343602 xxx n new True False False en
# medications 10114077010697624771 xxxx m ons True False False en
# , 2593208677638477497 , , , False False False en
# unknown 10430439674830883178 xxxx u own True False False en
# start 6480458294193393462 xxxx s art True False False en
# date 15387552459474943870 xxxx d ate True False False en
# and 2283656566040971221 xxx a and True False False en
# if 12446819118446800910 xx i if True False False en
# her 4115755726172261197 xxx h her True False False en
# HCP 2183834458705439728 XXX H HCP True False False en
# is 3411606890003347522 xx i is True False False en
# aware 15981128065641363532 xxxx a are True False False en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# to 3791531372978436496 xx t to True False False en
# start 6480458294193393462 xxxx s art True False False en
# generic 8919908555459875279 xxxx g ric True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# when 15807309897752499399 xxxx w hen True False False en
# finish 15571920043411331145 xxxx f ish True False False en
# her 4115755726172261197 xxx h her True False False en
# brand 3827899546313821993 xxxx b and True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# . 12646065887601541794 . . . False False False en
# No 9692231336188541085 Xx N No True False True en
# further 11294364119633739116 xxxx f her True False False en
# information 5552516367584430480 xxxx i ion True False False en
# was 9921686513378912864 xxx w was True False False en
# provided 333741129952275274 xxxx p ded True False False en
# . 12646065887601541794 . . . False False False en
# Follow 8297516985463436552 Xxxxx F low True False True en
# up 2199259611705938403 xx u up True False False en
# received 8054871301319024843 xxxx r ved True False False en
# on 5640369432778651323 xx o on True False False en
# 03 14784087551770123103 dd 0 03 False True False en
# - 9153284864653046197 - - - False False False en
# 01 2577082955473810581 dd 0 01 False True False en
# - 9153284864653046197 - - - False False False en
# 2018 14663858070065067916 dddd 2 018 False True False en
# . 12646065887601541794 . . . False False False en
# Updated 5472293035577438306 Xxxxx U ted True False True en
# on 5640369432778651323 xx o on True False False en
# 03 14784087551770123103 dd 0 03 False True False en
# - 9153284864653046197 - - - False False False en
# 01 2577082955473810581 dd 0 01 False True False en
# - 9153284864653046197 - - - False False False en
# 2018 14663858070065067916 dddd 2 018 False True False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# following 7893390400297566341 xxxx f ing True False False en
# should 10292920167869855674 xxxx s uld True False False en
# have 14692702688101715474 xxxx h ave True False False en
# been 12517269084653561647 xxxx b een True False False en
# included 9832579298474638421 xxxx i ded True False False en
# in 3002984154512732771 xx i in True False False en
# the 7425985699627899538 xxx t the True False False en
# above 12552628610781381849 xxxx a ove True False False en
# narrative 3030168271351040345 xxxx n ive True False False en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# stated 460014348387600406 xxxx s ted True False False en
# that 4380130941430378203 xxxx t hat True False False en
# she 6740321247510922449 xxx s she True False False en
# is 3411606890003347522 xx i is True False False en
# fine 16884455833306854589 xxxx f ine True False False en
# with 12510949447758279278 xxxx w ith True False False en
# the 7425985699627899538 xxx t the True False False en
# brand 3827899546313821993 xxxx b and True False False en
# Crestor 3637941411495505866 Xxxxx C tor True False True en
# , 2593208677638477497 , , , False False False en
# she 6740321247510922449 xxx s she True False False en
# no 13055779130471031426 xx n no True False False en
# problems 12400684381872086361 xxxx p ems True False False en
# with 12510949447758279278 xxxx w ith True False False en
# it 10239237003504588839 xx i it True False False en
# . 12646065887601541794 . . . False False False en
# This 12943039165150086467 Xxxx T his True False True en
# information 5552516367584430480 xxxx i ion True False False en
# was 9921686513378912864 xxx w was True False False en
# received 8054871301319024843 xxxx r ved True False False en
# in 3002984154512732771 xx i in True False False en
# the 7425985699627899538 xxx t the True False False en
# original 2076245830360176852 xxxx o nal True False False en
# phone 15861065479537671914 xxxx p one True False False en
# call 14229572451745258962 xxxx c all True False False en
# . 12646065887601541794 . . . False False False en
# Same 2914593513169084884 Xxxx S ame True False True en
# sender 1657759333876656104 xxxx s der True False False en
# table 10911622026469197494 xxxx t ble True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 1
# Call 11104957948539619373 Xxxx C all True False True en
# direct 3396428638438620601 xxxx d ect True False False en
# to 3791531372978436496 xx t to True False False en
# IC 9397940574446756610 XX I IC True False False en
# with 12510949447758279278 xxxx w ith True False False en
# XX 14968597813295776895 XX X XX True False False en
# and 2283656566040971221 xxx a and True False False en
# Me 17688641098104964042 Xx M Me True False True en
# related 9648789318421011716 xxxx r ted True False False en
# issue 4747730822158419200 xxxx i sue True False False en
# removal 10259646960330252655 xxxx r val True False False en
# of 886050111519832510 xx o of True False False en
# product 2104994216896503478 xxxx p uct True False False en
# letter 720313458719916916 xxxx l ter True False False en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# has 1248239241591158246 xxx h has True False False en
# been 12517269084653561647 xxxx b een True False False en
# prescribed 9829328753724449878 xxxx p bed True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# Rx 12127120578925786058 Xx R Rx True False True en
# capsule 76011155980193443 xxxx c ule True False False en
# . 12646065887601541794 . . . False False False en
# Long 10772215776554980285 Xxxx L ong True False True en
# term 4519742297340331040 xxxx t erm True False False en
# use 6873750497785110593 xxx u use True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# Rx 12127120578925786058 Xx R Rx True False True en
# . 12646065887601541794 . . . False False False en
# Event 5416805174850762202 Xxxxx E ent True False True en
# is 3411606890003347522 xx i is True False False en
# she 6740321247510922449 xxx s she True False False en
# took 1524062747651706878 xxxx t ook True False False en
# another 7270490914741406701 xxxx a her True False False en
# medication 13479940910518016904 xxxx m ion True False False en
# UNK 16544881809274863474 XXX U UNK True False False en
# not 447765159362469301 xxx n not True False False en
# specified 5692732795711286499 xxxx s ied True False False en
# which 7063653163634019529 xxxx w ich True False False en
# did 13583488448875926965 xxx d did True False False en
# not 447765159362469301 xxx n not True False False en
# help 17461235395181654430 xxxx h elp True False False en
# . 12646065887601541794 . . . False False False en
# This 12943039165150086467 Xxxx T his True False True en
# medication 13479940910518016904 xxxx m ion True False False en
# was 9921686513378912864 xxx w was True False False en
# for 16037325823156266367 xxx f for True False False en
# a 11901859001352538922 x a a True False False en
# medical 10039723232229819975 xxxx m cal True False False en
# condition 15050408803291667128 xxxx c ion True False False en
# not 447765159362469301 xxx n not True False False en
# specified 5692732795711286499 xxxx s ied True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# caller 5977827940815534873 xxxx c ler True False False en
# was 9921686513378912864 xxx w was True False False en
# not 447765159362469301 xxx n not True False False en
# sure 2985827712170516640 xxxx s ure True False False en
# why 16315412628806490806 xxx w why True False False en
# she 6740321247510922449 xxx s she True False False en
# took 1524062747651706878 xxxx t ook True False False en
# the 7425985699627899538 xxx t the True False False en
# medication 13479940910518016904 xxxx m ion True False False en
# . 12646065887601541794 . . . False False False en
# It 7859011591137717335 Xx I It True False True en
# was 9921686513378912864 xxx w was True False False en
# possibly 10407344142452042049 xxxx p bly True False False en
# for 16037325823156266367 xxx f for True False False en
# anxiety 3518314200804635422 xxxx a ety True False False en
# or 3740602843040177340 xx o or True False False en
# depression 12339746114146696307 xxxx d ion True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# noticed 16682126538620412122 xxxx n ced True False False en
# the 7425985699627899538 xxx t the True False False en
# medication 13479940910518016904 xxxx m ion True False False en
# did 13583488448875926965 xxx d did True False False en
# not 447765159362469301 xxx n not True False False en
# work 10038440415813069799 xxxx w ork True False False en
# after 13428508259213873547 xxxx a ter True False False en
# she 6740321247510922449 xxx s she True False False en
# started 17976686883172633439 xxxx s ted True False False en
# the 7425985699627899538 xxx t the True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# Rx 12127120578925786058 Xx R Rx True False True en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# stated 460014348387600406 xxxx s ted True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# Rx 12127120578925786058 Xx R Rx True False True en
# is 3411606890003347522 xx i is True False False en
# the 7425985699627899538 xxx t the True False False en
# only 13398675276606405380 xxxx o nly True False False en
# thing 2473243759842082748 xxxx t ing True False False en
# that 4380130941430378203 xxxx t hat True False False en
# helps 245637087864966835 xxxx h lps True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# stated 460014348387600406 xxxx s ted True False False en
# that 4380130941430378203 xxxx t hat True False False en
# in 3002984154512732771 xx i in True False False en
# the 7425985699627899538 xxx t the True False False en
# past 14080206577736366893 xxxx p ast True False False en
# she 6740321247510922449 xxx s she True False False en
# has 1248239241591158246 xxx h has True False False en
# had 12960022596163002503 xxx h had True False False en
# a 11901859001352538922 x a a True False False en
# flare 12444842693061132442 xxxx f are True False False en
# up 2199259611705938403 xx u up True False False en
# due 3766551886407196655 xxx d due True False False en
# to 3791531372978436496 xx t to True False False en
# stress 2754663265045775480 xxxx s ess True False False en
# or 3740602843040177340 xx o or True False False en
# due 3766551886407196655 xxx d due True False False en
# to 3791531372978436496 xx t to True False False en
# being 3899131925553995529 xxxx b ing True False False en
# on 5640369432778651323 xx o on True False False en
# an 15099054000809333061 xx a an True False False en
# antibiotic 7941236663047931822 xxxx a tic True False False en
# or 3740602843040177340 xx o or True False False en
# eating 12092082220177030354 xxxx e ing True False False en
# certain 4103828292747546490 xxxx c ain True False False en
# foods 15872556548229247504 xxxx f ods True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# declined 7920570735177562949 xxxx d ned True False False en
# to 3791531372978436496 xx t to True False False en
# provide 3805418597433244348 xxxx p ide True False False en
# any 13148361048351484388 xxx a any True False False en
# additional 2629337523440010198 xxxx a nal True False False en
# information 5552516367584430480 xxxx i ion True False False en
# for 16037325823156266367 xxx f for True False False en
# this 1995909169258310477 xxxx t his True False False en
# report 2729752284408055516 xxxx r ort True False False en
# . 12646065887601541794 . . . False False False en
# Dates 12714343888120465331 Xxxxx D tes True False True en
# could 7494117911267222209 xxxx c uld True False False en
# not 447765159362469301 xxx n not True False False en
# be 10382539506755952630 xx b be True False False en
# clarified 9828870682067737521 xxxx c ied True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# declined 7920570735177562949 xxxx d ned True False False en
# follow 14462500713227930305 xxxx f low True False False en
# up 2199259611705938403 xx u up True False False en
# from 7831658034963690409 xxxx f rom True False False en
# patient 14577208587912523278 xxxx p ent True False False en
# safety 1869645994878888584 xxxx s ety True False False en
# and 2283656566040971221 xxx a and True False False en
# for 16037325823156266367 xxx f for True False False en
# permission 3245052208806508196 xxxx p ion True False False en
# to 3791531372978436496 xx t to True False False en
# contact 786451873915755474 xxxx c act True False False en
# HCP 2183834458705439728 XXX H HCP True False False en
# . 12646065887601541794 . . . False False False en
# SJ 6620778771261562426 XX S SJ True False False en
# ( 12638816674900267446 ( ( ( False False False en
# TMS 17290273522783160833 XXX T TMS True False False en
# ) 3842344029291005339 ) ) ) False False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 2
# XX 14968597813295776895 XX X XX True False False en
# and 2283656566040971221 xxx a and True False False en
# Me 17688641098104964042 Xx M Me True False True en
# agent 398 xxxx a ent True False False en
# called 3125235652374451650 xxxx c led True False False en
# to 3791531372978436496 xx t to True False False en
# report 2729752284408055516 xxxx r ort True False False en
# an 15099054000809333061 xx a an True False False en
# adverse 10274160298693536259 xxxx a rse True False False en
# event 16065740214838660377 xxxx e ent True False False en
# on 5640369432778651323 xx o on True False False en
# behalf 15927626727734925895 xxxx b alf True False False en
# of 886050111519832510 xx o of True False False en
# a 11901859001352538922 x a a True False False en
# consumer 822906622843328326 xxxx c mer True False False en
# who 3876862883474502309 xxx w who True False False en
# was 9921686513378912864 xxx w was True False False en
# no 13055779130471031426 xx n no True False False en
# longer 2041435544530518504 xxxx l ger True False False en
# on 5640369432778651323 xx o on True False False en
# the 7425985699627899538 xxx t the True False False en
# line 9545763306533606446 xxxx l ine True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# consumer 822906622843328326 xxxx c mer True False False en
# began 10945255555151935078 xxxx b gan True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# 40 5087266072664039774 dd 4 40 False True False en
# mg 722646293792979593 xx m mg True False False en
# once 18381768081115421630 xxxx o nce True False False en
# a 11901859001352538922 x a a True False False en
# day 1608482186128794349 xxx d day True False False en
# , 2593208677638477497 , , , False False False en
# for 16037325823156266367 xxx f for True False False en
# acid 7562692243244894168 xxxx a cid True False False en
# reflux 1067400472207317658 xxxx r lux True False False en
# , 2593208677638477497 , , , False False False en
# start 6480458294193393462 xxxx s art True False False en
# date 15387552459474943870 xxxx d ate True False False en
# not 447765159362469301 xxx n not True False False en
# reported 11181246799942687462 xxxx r ted True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# consumer 822906622843328326 xxxx c mer True False False en
# reported 11181246799942687462 xxxx r ted True False False en
# that 4380130941430378203 xxxx t hat True False False en
# her 4115755726172261197 xxx h her True False False en
# acid 7562692243244894168 xxxx a cid True False False en
# reflux 1067400472207317658 xxxx r lux True False False en
# was 9921686513378912864 xxx w was True False False en
# worse 15932487760797679903 xxxx w rse True False False en
# past 14080206577736366893 xxxx p ast True False False en
# couple 16116837014497452873 xxxx c ple True False False en
# days 18443948407981750281 xxxx d ays True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# reported 11181246799942687462 xxxx r ted True False False en
# having 8813345386932560795 xxxx h ing True False False en
# extreme 7331532195515971780 xxxx e eme True False False en
# stress 2754663265045775480 xxxx s ess True False False en
# , 2593208677638477497 , , , False False False en
# heart 12419898511841729938 xxxx h art True False False en
# burn 12905682277821018784 xxxx b urn True False False en
# and 2283656566040971221 xxx a and True False False en
# is 3411606890003347522 xx i is True False False en
# not 447765159362469301 xxx n not True False False en
# eating 12092082220177030354 xxxx e ing True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# consumer 822906622843328326 xxxx c mer True False False en
# further 11294364119633739116 xxxx f her True False False en
# clarified 9828870682067737521 xxxx c ied True False False en
# that 4380130941430378203 xxxx t hat True False False en
# because 16950148841647037698 xxxx b use True False False en
# of 886050111519832510 xx o of True False False en
# her 4115755726172261197 xxx h her True False False en
# acid 7562692243244894168 xxxx a cid True False False en
# reflux 1067400472207317658 xxxx r lux True False False en
# getting 1385318218384692368 xxxx g ing True False False en
# worse 15932487760797679903 xxxx w rse True False False en
# her 4115755726172261197 xxx h her True False False en
# doctor 18058202148154971361 xxxx d tor True False False en
# increased 17677145775322650395 xxxx i sed True False False en
# her 4115755726172261197 xxx h her True False False en
# dose 3913336927868767965 xxxx d ose True False False en
# to 3791531372978436496 xx t to True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# 40 5087266072664039774 dd 4 40 False True False en
# mg 722646293792979593 xx m mg True False False en
# twice 12432145235342457793 xxxx t ice True False False en
# a 11901859001352538922 x a a True False False en
# day 1608482186128794349 xxx d day True False False en
# starting 17219656379376048755 xxxx s ing True False False en
# today 11042482332948150395 xxxx t day True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# consumer 822906622843328326 xxxx c mer True False False en
# was 9921686513378912864 xxx w was True False False en
# no 13055779130471031426 xx n no True False False en
# longer 2041435544530518504 xxxx l ger True False False en
# on 5640369432778651323 xx o on True False False en
# the 7425985699627899538 xxx t the True False False en
# line 9545763306533606446 xxxx l ine True False False en
# and 2283656566040971221 xxx a and True False False en
# was 9921686513378912864 xxx w was True False False en
# unable 5479078682019508 xxxx u ble True False False en
# to 3791531372978436496 xx t to True False False en
# provide 3805418597433244348 xxxx p ide True False False en
# additional 2629337523440010198 xxxx a nal True False False en
# information 5552516367584430480 xxxx i ion True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 3
# Patient 9416364957002412138 Xxxxx P ent True False True en
# advised 15715586425206156552 xxxx a sed True False False en
# that 4380130941430378203 xxxx t hat True False False en
# she 6740321247510922449 xxx s she True False False en
# had 12960022596163002503 xxx h had True False False en
# taken 10068469413441223976 xxxx t ken True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# in 3002984154512732771 xx i in True False False en
# the 7425985699627899538 xxx t the True False False en
# past 14080206577736366893 xxxx p ast True False False en
# the 7425985699627899538 xxx t the True False False en
# was 9921686513378912864 xxx w was True False False en
# switched 1554613828843916867 xxxx s hed True False False en
# to 3791531372978436496 xx t to True False False en
# the 7425985699627899538 xxx t the True False False en
# generic 8919908555459875279 xxxx g ric True False False en
# and 2283656566040971221 xxx a and True False False en
# then 2630753287402592467 xxxx t hen True False False en
# back 15255859468896132977 xxxx b ack True False False en
# to 3791531372978436496 xx t to True False False en
# Nexium 6675581809462397983 Xxxxx N ium True False True en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# advised 15715586425206156552 xxxx a sed True False False en
# that 4380130941430378203 xxxx t hat True False False en
# the 7425985699627899538 xxx t the True False False en
# generic 8919908555459875279 xxxx g ric True False False en
# does 1818273248662495384 xxxx d oes True False False en
# nt 9353232606613764737 xx n nt True False False en
# work 10038440415813069799 xxxx w ork True False False en
# for 16037325823156266367 xxx f for True False False en
# her 4115755726172261197 xxx h her True False False en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# declined 7920570735177562949 xxxx d ned True False False en
# to 3791531372978436496 xx t to True False False en
# provide 3805418597433244348 xxxx p ide True False False en
# any 13148361048351484388 xxx a any True False False en
# further 11294364119633739116 xxxx f her True False False en
# information 5552516367584430480 xxxx i ion True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 4
# Email 11010771136823990775 Xxxxx E ail True False True en
# correspondence 11310010288497220647 xxxx c nce True False False en
# received 8054871301319024843 xxxx r ved True False False en
# from 7831658034963690409 xxxx f rom True False False en
# XX 14968597813295776895 XX X XX True False False en
# and 2283656566040971221 xxx a and True False False en
# Me 17688641098104964042 Xx M Me True False True en
# . 12646065887601541794 . . . False False False en
# Adverse 7092613754313174695 Xxxxx A rse True False True en
# Event 5416805174850762202 Xxxxx E ent True False True en
# was 9921686513378912864 xxx w was True False False en
# received 8054871301319024843 xxxx r ved True False False en
# from 7831658034963690409 xxxx f rom True False False en
# XX 14968597813295776895 XX X XX True False False en
# and 2283656566040971221 xxx a and True False False en
# Me 17688641098104964042 Xx M Me True False True en
# by 16764210730586636600 xx b by True False False en
# email 7320900731437023467 xxxx e ail True False False en
# , 2593208677638477497 , , , False False False en
# as 7437575085468336610 xx a as True False False en
# they 16875582379069451158 xxxx t hey True False False en
# were 9570894245975188254 xxxx w ere True False False en
# unable 5479078682019508 xxxx u ble True False False en
# to 3791531372978436496 xx t to True False False en
# contact 786451873915755474 xxxx c act True False False en
# the 7425985699627899538 xxx t the True False False en
# IC 9397940574446756610 XX I IC True False False en
# by 16764210730586636600 xx b by True False False en
# phone 15861065479537671914 xxxx p one True False False en
# , 2593208677638477497 , , , False False False en
# no 13055779130471031426 xx n no True False False en
# attachments 3289764938820885300 xxxx a nts True False False en
# are 5012629990875267006 xxx a are True False False en
# associated 18191730948251606032 xxxx a ted True False False en
# with 12510949447758279278 xxxx w ith True False False en
# this 1995909169258310477 xxxx t his True False False en
# case 8110129090154140942 xxxx c ase True False False en
# . 12646065887601541794 . . . False False False en
# Subject 10828730662571105685 Xxxxx S ect True False True en
# This 12943039165150086467 Xxxx T his True False True en
# is 3411606890003347522 xx i is True False False en
# a 11901859001352538922 x a a True False False en
# possible 1322442146463163273 xxxx p ble True False False en
# AE 10914878996140809769 XX A AE True False False en
# , 2593208677638477497 , , , False False False en
# PQC 10903170496810338999 XXX P PQC True False False en
# , 2593208677638477497 , , , False False False en
# or 3740602843040177340 xx o or True False False en
# Medical 10117188822904858183 Xxxxx M cal True False True en
# / 2466615745961202537 / / / False False False en
# Product 16898055450696666743 Xxxxx P uct True False True en
# Inquiry 17963336831302261445 Xxxxx I iry True False True en
# from 7831658034963690409 xxxx f rom True False False en
# XXandMe 8726000012066756568 XXxxxXx X dMe True False False en
# inVentiv 5867855210258350030 xxXxxxx i tiv True False False en
# . 12646065887601541794 . . . False False False en
# Please 10460112544927249051 Xxxxx P ase True False True en
# treat 18064169627558009102 xxxx t eat True False False en
# this 1995909169258310477 xxxx t his True False False en
# as 7437575085468336610 xx a as True False False en
# an 15099054000809333061 xx a an True False False en
# urgent 5335761943521943035 xxxx u ent True False False en
# case 8110129090154140942 xxxx c ase True False False en
# . 12646065887601541794 . . . False False False en
# AE 10914878996140809769 XX A AE True False False en
# received 8054871301319024843 xxxx r ved True False False en
# by 16764210730586636600 xx b by True False False en
# phone 15861065479537671914 xxxx p one True False False en
# on 5640369432778651323 xx o on True False False en
# 21 4686009691886217934 dd 2 21 False True False en
# - 9153284864653046197 - - - False False False en
# 09 7095440179426340912 dd 0 09 False True False en
# - 9153284864653046197 - - - False False False en
# 2015 5268047934427719614 dddd 2 015 False True False en
# . 12646065887601541794 . . . False False False en
# Information 7262725514246706477 Xxxxx I ion True False True en
# that 4380130941430378203 xxxx t hat True False False en
# includes 14932704014687019645 xxxx i des True False False en
# the 7425985699627899538 xxx t the True False False en
# PERD 5244014643262858548 XXXX P ERD True False False en
# requirements 6276331263190046164 xxxx r nts True False False en
# or 3740602843040177340 xx o or True False False en
# PQC 10903170496810338999 XXX P PQC True False False en
# requirements 6276331263190046164 xxxx r nts True False False en
# is 3411606890003347522 xx i is True False False en
# provided 333741129952275274 xxxx p ded True False False en
# . 12646065887601541794 . . . False False False en
# Text 17062258109916561512 Xxxx T ext True False True en
# Body 712296055433963987 Xxxx B ody True False True en
# Date:21 8835245577630054757 Xxxx:dd D :21 False False True en
# - 9153284864653046197 - - - False False False en
# 09 7095440179426340912 dd 0 09 False True False en
# - 9153284864653046197 - - - False False False en
# 2015 5268047934427719614 dddd 2 015 False True False en
# How 16762307017182994292 Xxx H How True False True en
# was 9921686513378912864 xxx w was True False False en
# it 10239237003504588839 xx i it True False False en
# received 8054871301319024843 xxxx r ved True False False en
# : 11532473245541075862 : : : False False False en
# PHONE 18029101687566620141 XXXX P ONE True False False en
# Time 6003654503447485829 Xxxx T ime True False True en
# reported:2:50 16705808858775820142 xxxx:d:dd r :50 False False False en
# p.m. 367645567677572359 x.x. p .m. False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# information 5552516367584430480 xxxx i ion True False False en
# : 11532473245541075862 : : : False False False en
# Pamela 13540248457164462235 Xxxxx P ela True False True en
# Desjardins 5536224323118768080 Xxxxx D ins True False True en
# , 2593208677638477497 , , , False False False en
# XX 14968597813295776895 XX X XX True False False en
# , 2593208677638477497 , , , False False False en
# , 2593208677638477497 , , , False False False en
# xxx.xx.0246(DIS 12771612920188394284 xxx.xx.dddd(XXX x DIS False False False en
# removed 13581665348131931927 xxxx r ved True False False en
# numbers 16181666555170135050 xxxx n ers True False False en
# from 7831658034963690409 xxxx f rom True False False en
# Social 5081278329404970534 Xxxxx S ial True False True en
# Security 2911704783067235766 Xxxxx S ity True False True en
# number 429 xxxx n ber True False False en
# and 2283656566040971221 xxx a and True False False en
# replaced 10754934536441777878 xxxx r ced True False False en
# with 12510949447758279278 xxxx w ith True False False en
# xxx 4088098365541558500 xxx x xxx True False False en
# for 16037325823156266367 xxx f for True False False en
# privacy 9394217028216858347 xxxx p acy True False False en
# ) 3842344029291005339 ) ) ) False False False en
# Event 5416805174850762202 Xxxxx E ent True False True en
# : 11532473245541075862 : : : False False False en
# Pt 8629887346712643445 Xx P Pt True False True en
# has 1248239241591158246 xxx h has True False False en
# missed 18163165972514536835 xxxx m sed True False False en
# 2 15180167692696242062 d 2 2 False True False en
# days 18443948407981750281 xxxx d ays True False False en
# of 886050111519832510 xx o of True False False en
# meds 15857012054290625897 xxxx m eds True False False en
# Reporter 10059315931948973322 Xxxxx R ter True False True en
# : 11532473245541075862 : : : False False False en
# Pamela 13540248457164462235 Xxxxx P ela True False True en
# Desjardins 5536224323118768080 Xxxxx D ins True False True en
# Drug 15085802872750384791 Xxxx D rug True False True en
# : 11532473245541075862 : : : False False False en
# Seroquel 11836967944913224606 Xxxxx S uel True False True en
# XR 6947724957259345882 XX X XR True False False en
# 400 12495206808265140655 ddd 4 400 False True False en
# mg 722646293792979593 xx m mg True False False en
# tab 16686851913265654913 xxx t tab True False False en
# No 9692231336188541085 Xx N No True False True en
# other 1176656782636220709 xxxx o her True False False en
# information 5552516367584430480 xxxx i ion True False False en
# provided 333741129952275274 xxxx p ded True False False en
# . 12646065887601541794 . . . False False False en
# No 9692231336188541085 Xx N No True False True en
# permission 3245052208806508196 xxxx p ion True False False en
# provided 333741129952275274 xxxx p ded True False False en
# for 16037325823156266367 xxx f for True False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# Safety 1317358255061938110 Xxxxx S ety True False True en
# to 3791531372978436496 xx t to True False False en
# recontact 3638443025381672844 xxxx r act True False False en
# Reporter 10059315931948973322 Xxxxx R ter True False True en
# or 3740602843040177340 xx o or True False False en
# to 3791531372978436496 xx t to True False False en
# contact 786451873915755474 xxxx c act True False False en
# HCP.JN(TMS 10119634263670438868 XXX.XX(XXX H TMS False False False en
# ) 3842344029291005339 ) ) ) False False False en
# Follow 8297516985463436552 Xxxxx F low True False True en
# up 2199259611705938403 xx u up True False False en
# received 8054871301319024843 xxxx r ved True False False en
# on 5640369432778651323 xx o on True False False en
# 04 9920090784869387584 dd 0 04 False True False en
# - 9153284864653046197 - - - False False False en
# 12 1124146173557384544 dd 1 12 False True False en
# - 9153284864653046197 - - - False False False en
# 2017 12587536829529815270 dddd 2 017 False True False en
# . 12646065887601541794 . . . False False False en
# Enrolled 90313508550877251 Xxxxx E led True False True en
# patient 14577208587912523278 xxxx p ent True False False en
# transferred 10904629011691553064 xxxx t red True False False en
# from 7831658034963690409 xxxx f rom True False False en
# XX 14968597813295776895 XX X XX True False False en
# and 2283656566040971221 xxx a and True False False en
# Me 17688641098104964042 Xx M Me True False True en
# . 12646065887601541794 . . . False False False en
# 2 15180167692696242062 d 2 2 False True False en
# to 3791531372978436496 xx t to True False False en
# 3 602994839685422785 d 3 3 False True False en
# years 9492612516460955585 xxxx y ars True False False en
# ago 18432988265768819336 xxx a ago True False False en
# she 6740321247510922449 xxx s she True False False en
# did 13583488448875926965 xxx d did True False False en
# not 447765159362469301 xxx n not True False False en
# do 2158845516055552166 xx d do True False False en
# well 4525988469032889948 xxxx w ell True False False en
# on 5640369432778651323 xx o on True False False en
# the 7425985699627899538 xxx t the True False False en
# generic 8919908555459875279 xxxx g ric True False False en
# Seroquel 11836967944913224606 Xxxxx S uel True False True en
# XR 6947724957259345882 XX X XR True False False en
# , 2593208677638477497 , , , False False False en
# exact 16933942822082371337 xxxx e act True False False en
# date 15387552459474943870 xxxx d ate True False False en
# unknown 10430439674830883178 xxxx u own True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# clarified 9828870682067737521 xxxx c ied True False False en
# by 16764210730586636600 xx b by True False False en
# stating 10618686891247304506 xxxx s ing True False False en
# that 4380130941430378203 xxxx t hat True False False en
# while 1039541750886098100 xxxx w ile True False False en
# she 6740321247510922449 xxx s she True False False en
# was 9921686513378912864 xxx w was True False False en
# using 16421957100465448365 xxxx u ing True False False en
# the 7425985699627899538 xxx t the True False False en
# generic 8919908555459875279 xxxx g ric True False False en
# for 16037325823156266367 xxx f for True False False en
# 30 17750038938330149908 dd 3 30 False True False en
# days 18443948407981750281 xxxx d ays True False False en
# , 2593208677638477497 , , , False False False en
# she 6740321247510922449 xxx s she True False False en
# did 13583488448875926965 xxx d did True False False en
# not 447765159362469301 xxx n not True False False en
# sleep 9840574412351606749 xxxx s eep True False False en
# well 4525988469032889948 xxxx w ell True False False en
# and 2283656566040971221 xxx a and True False False en
# was 9921686513378912864 xxx w was True False False en
# shaky 5993504102340924037 xxxx s aky True False False en
# . 12646065887601541794 . . . False False False en
# Her 452811260292132302 Xxx H Her True False True en
# HCP 2183834458705439728 XXX H HCP True False False en
# was 9921686513378912864 xxx w was True False False en
# aware 15981128065641363532 xxxx a are True False False en
# and 2283656566040971221 xxx a and True False False en
# switched 1554613828843916867 xxxx s hed True False False en
# her 4115755726172261197 xxx h her True False False en
# back 15255859468896132977 xxxx b ack True False False en
# to 3791531372978436496 xx t to True False False en
# Seroquel 11836967944913224606 Xxxxx S uel True False True en
# XR 6947724957259345882 XX X XR True False False en
# brand 3827899546313821993 xxxx b and True False False en
# and 2283656566040971221 xxx a and True False False en
# those 5224941539530611462 xxxx t ose True False False en
# symptoms 15464668400958984916 xxxx s oms True False False en
# resolved 8507372808354681079 xxxx r ved True False False en
# . 12646065887601541794 . . . False False False en
# Her 452811260292132302 Xxx H Her True False True en
# pharmacist 10796916476975149127 xxxx p ist True False False en
# told 1245643389253732868 xxxx t old True False False en
# her 4115755726172261197 xxx h her True False False en
# it 10239237003504588839 xx i it True False False en
# may 14378475389916013800 xxx m may True False False en
# have 14692702688101715474 xxxx h ave True False False en
# been 12517269084653561647 xxxx b een True False False en
# due 3766551886407196655 xxx d due True False False en
# to 3791531372978436496 xx t to True False False en
# the 7425985699627899538 xxx t the True False False en
# fillers 10039300337188254064 xxxx f ers True False False en
# . 12646065887601541794 . . . False False False en
# PS 3115038707887812312 XX P PS True False False en
# granted 7640242612580250176 xxxx g ted True False False en
# permission 3245052208806508196 xxxx p ion True False False en
# to 3791531372978436496 xx t to True False False en
# contact 786451873915755474 xxxx c act True False False en
# patient 14577208587912523278 xxxx p ent True False False en
# . 12646065887601541794 . . . False False False en
# Her 452811260292132302 Xxx H Her True False True en
# address 14349763737243715186 xxxx a ess True False False en
# is 3411606890003347522 xx i is True False False en
# as 7437575085468336610 xx a as True False False en
# stated 460014348387600406 xxxx s ted True False False en
# above 12552628610781381849 xxxx a ove True False False en
# , 2593208677638477497 , , , False False False en
# her 4115755726172261197 xxx h her True False False en
# email 7320900731437023467 xxxx e ail True False False en
# is 3411606890003347522 xx i is True False False en
# xxx@yahoo.com 14586255630839386682 xxx@xxxx.xxx x com False False False en
# , 2593208677638477497 , , , False False False en
# and 2283656566040971221 xxx a and True False False en
# her 4115755726172261197 xxx h her True False False en
# phone 15861065479537671914 xxxx p one True False False en
# number 429 xxxx n ber True False False en
# is 3411606890003347522 xx i is True False False en
# 480.300.9210 5334419695140477165 ddd.ddd.dddd 4 210 False False False en
# . 12646065887601541794 . . . False False False en
# PS 3115038707887812312 XX P PS True False False en
# also 12084876542534825196 xxxx a lso True False False en
# has 1248239241591158246 xxx h has True False False en
# permission 3245052208806508196 xxxx p ion True False False en
# to 3791531372978436496 xx t to True False False en
# contact 786451873915755474 xxxx c act True False False en
# her 4115755726172261197 xxx h her True False False en
# HCP 2183834458705439728 XXX H HCP True False False en
# Dr. 12921814047719899021 Xx. D Dr. False False True en
# Michael 7950405567969217468 Xxxxx M ael True False True en
# Mar 12595687976425261068 Xxx M Mar True False True en
# practicing 4931623289020912954 xxxx p ing True False False en
# . 12646065887601541794 . . . False False False en
# No 9692231336188541085 Xx N No True False True en
# further 11294364119633739116 xxxx f her True False False en
# information 5552516367584430480 xxxx i ion True False False en
# provided 333741129952275274 xxxx p ded True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 5
# The 5059648917813135842 Xxx T The True False True en
# patients 9411398066792923322 xxxx p nts True False False en
# daughter 10838604093892214417 xxxx d ter True False False en
# reports 11419729215522767315 xxxx r rts True False False en
# her 4115755726172261197 xxx h her True False False en
# mother 7963322251145911254 xxxx m her True False False en
# has 1248239241591158246 xxx h has True False False en
# been 12517269084653561647 xxxx b een True False False en
# having 8813345386932560795 xxxx h ing True False False en
# " 15884554869126768810 " " " False False False en
# abdominal 4825016277875502055 xxxx a nal True False False en
# burning 7286610758523285992 xxxx b ing True False False en
# pains 18078697605794065772 xxxx p ins True False False en
# " 15884554869126768810 " " " False False False en
# since 10066841407251338481 xxxx s nce True False False en
# starting 17219656379376048755 xxxx s ing True False False en
# the 7425985699627899538 xxx t the True False False en
# Lynparza 11607701012143537878 Xxxxx L rza True False True en
# . 12646065887601541794 . . . False False False en
# Patient 9416364957002412138 Xxxxx P ent True False True en
# had 12960022596163002503 xxx h had True False False en
# labs 1955323671506040594 xxxx l abs True False False en
# drawn 4626310671846552529 xxxx d awn True False False en
# and 2283656566040971221 xxx a and True False False en
# saw 15201910715624124754 xxx s saw True False False en
# her 4115755726172261197 xxx h her True False False en
# oncologist 2116391217475758588 xxxx o ist True False False en
# yesterday 1756787072497230782 xxxx y day True False False en
# and 2283656566040971221 xxx a and True False False en
# informed 2537872997886871862 xxxx i med True False False en
# him 1739263527992748485 xxx h him True False False en
# of 886050111519832510 xx o of True False False en
# her 4115755726172261197 xxx h her True False False en
# symptoms 15464668400958984916 xxxx s oms True False False en
# . 12646065887601541794 . . . False False False en
# Her 452811260292132302 Xxx H Her True False True en
# labs 1955323671506040594 xxxx l abs True False False en
# were 9570894245975188254 xxxx w ere True False False en
# all 13409319323822384369 xxx a all True False False en
# okay 6434282243460496691 xxxx o kay True False False en
# and 2283656566040971221 xxx a and True False False en
# the 7425985699627899538 xxx t the True False False en
# oncologist 2116391217475758588 xxxx o ist True False False en
# examined 15282224634967800253 xxxx e ned True False False en
# the 7425985699627899538 xxx t the True False False en
# patient 14577208587912523278 xxxx p ent True False False en
# but 14560795576765492085 xxx b but True False False en
# did 13583488448875926965 xxx d did True False False en
# not 447765159362469301 xxx n not True False False en
# give 11640825575873464194 xxxx g ive True False False en
# her 4115755726172261197 xxx h her True False False en
# anything 10624292618385541108 xxxx a ing True False False en
# for 16037325823156266367 xxx f for True False False en
# her 4115755726172261197 xxx h her True False False en
# stomach 10587587228259269356 xxxx s ach True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 6
# Patients 7870152712391742528 Xxxxx P nts True False True en
# husband 16735199241396959768 xxxx h and True False False en
# reported 11181246799942687462 xxxx r ted True False False en
# she 6740321247510922449 xxx s she True False False en
# has 1248239241591158246 xxx h has True False False en
# nausea 15418423311033015569 xxxx n sea True False False en
# , 2593208677638477497 , , , False False False en
# vomiting 6147468973368432127 xxxx v ing True False False en
# , 2593208677638477497 , , , False False False en
# " 15884554869126768810 " " " False False False en
# ca 13913074996085095135 xx c ca True False False en
# nt 9353232606613764737 xx n nt True False False en
# eat 9837207709914848172 xxx e eat True False False en
# " 15884554869126768810 " " " False False False en
# and 2283656566040971221 xxx a and True False False en
# is 3411606890003347522 xx i is True False False en
# unable 5479078682019508 xxxx u ble True False False en
# to 3791531372978436496 xx t to True False False en
# sleep 9840574412351606749 xxxx s eep True False False en
# . 12646065887601541794 . . . False False False en
# He 1692983299745037067 Xx H He True False True en
# reports 11419729215522767315 xxxx r rts True False False en
# that 4380130941430378203 xxxx t hat True False False en
# patients 9411398066792923322 xxxx p nts True False False en
# labs 1955323671506040594 xxxx l abs True False False en
# have 14692702688101715474 xxxx h ave True False False en
# been 12517269084653561647 xxxx b een True False False en
# okay 6434282243460496691 xxxx o kay True False False en
# but 14560795576765492085 xxx b but True False False en
# her 4115755726172261197 xxx h her True False False en
# RBCs 12500864938500063302 XXXx R BCs True False False en
# are 5012629990875267006 xxx a are True False False en
# slightly 16645327642385258788 xxxx s tly True False False en
# low 14075063713394987089 xxx l low True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en
# Paragraph number... 7
# One 12491099834491675542 Xxx O One True False True en
# 25 4522981160172931067 dd 2 25 False True False en
# years 9492612516460955585 xxxx y ars True False False en
# old 2483095116303079762 xxx o old True False False en
# female 194700782214550345 xxxx f ale True False False en
# patient 14577208587912523278 xxxx p ent True False False en
# received 8054871301319024843 xxxx r ved True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# 160 11641201567768325302 ddd 1 160 False True False en
# ug 15060655763940145774 xx u ug True False False en
# bid 15851398737023972976 xxx b bid True False False en
# for 16037325823156266367 xxx f for True False False en
# asthma 13804933907730890588 xxxx a hma True False False en
# via 17875975611192538924 xxx v via True False False en
# prescription 9002369395942733371 xxxx p ion True False False en
# since 10066841407251338481 xxxx s nce True False False en
# over 5456543204961066030 xxxx o ver True False False en
# one 17454115351911680600 xxx o one True False False en
# month 14920206370424861916 xxxx m nth True False False en
# ago 18432988265768819336 xxx a ago True False False en
# . 12646065887601541794 . . . False False False en
# No 9692231336188541085 Xx N No True False True en
# other 1176656782636220709 xxxx o her True False False en
# medical 10039723232229819975 xxxx m cal True False False en
# history 6249630248276940353 xxxx h ory True False False en
# . 12646065887601541794 . . . False False False en
# One 12491099834491675542 Xxx O One True False True en
# week 14249255431398666181 xxxx w eek True False False en
# after 13428508259213873547 xxxx a ter True False False en
# medication 13479940910518016904 xxxx m ion True False False en
# her 4115755726172261197 xxx h her True False False en
# face 17395397334214475556 xxxx f ace True False False en
# appeared 1180560496108331684 xxxx a red True False False en
# rash 12474082149336105449 xxxx r ash True False False en
# vesicular(little 12588919647692807385 xxxx(xxxx v tle False False False en
# blisters 6232177479578571917 xxxx b ers True False False en
# accompanying 11179507592162685346 xxxx a ing True False False en
# with 12510949447758279278 xxxx w ith True False False en
# pain 8558038558878807367 xxxx p ain True False False en
# ) 3842344029291005339 ) ) ) False False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# visited 11749534953085588517 xxxx v ted True False False en
# pneumology 5773139985189121586 xxxx p ogy True False False en
# department 16994674601229482777 xxxx d ent True False False en
# , 2593208677638477497 , , , False False False en
# the 7425985699627899538 xxx t the True False False en
# doctor 18058202148154971361 xxxx d tor True False False en
# said 17573686707662795042 xxxx s aid True False False en
# allergic 8876943098324347428 xxxx a gic True False False en
# symptom 16190201684402242524 xxxx s tom True False False en
# of 886050111519832510 xx o of True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# was 9921686513378912864 xxx w was True False False en
# rare 569577313127347749 xxxx r are True False False en
# , 2593208677638477497 , , , False False False en
# it 10239237003504588839 xx i it True False False en
# was 9921686513378912864 xxx w was True False False en
# uncertainly 12784475461921048515 xxxx u nly True False False en
# caused 2948292233719154075 xxxx c sed True False False en
# by 16764210730586636600 xx b by True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# . 12646065887601541794 . . . False False False en
# Dermatologist 737747913668881423 Xxxxx D ist True False True en
# said 17573686707662795042 xxxx s aid True False False en
# it 10239237003504588839 xx i it True False False en
# might 9067754100579305666 xxxx m ght True False False en
# be 10382539506755952630 xx b be True False False en
# caused 2948292233719154075 xxxx c sed True False False en
# by 16764210730586636600 xx b by True False False en
# hormone 10329349054803722659 xxxx h one True False False en
# ingredient 1823163430043671446 xxxx i ent True False False en
# of 886050111519832510 xx o of True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# smeared 10902897505753196507 xxxx s red True False False en
# Ganciclovir 4962715873330403722 Xxxxx G vir True False True en
# Gel 3539750630168176836 Xxx G Gel True False True en
# and 2283656566040971221 xxx a and True False False en
# then 2630753287402592467 xxxx t hen True False False en
# the 7425985699627899538 xxx t the True False False en
# AE 10914878996140809769 XX A AE True False False en
# was 9921686513378912864 xxx w was True False False en
# improved 3813719572866565009 xxxx i ved True False False en
# . 12646065887601541794 . . . False False False en
# But 18004243461113809161 Xxx B But True False True en
# rash 12474082149336105449 xxxx r ash True False False en
# vesicular 9347358192802220709 xxxx v lar True False False en
# would 6992604926141104606 xxxx w uld True False False en
# recur 8755862117782530844 xxxx r cur True False False en
# when 15807309897752499399 xxxx w hen True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# was 9921686513378912864 xxx w was True False False en
# received 8054871301319024843 xxxx r ved True False False en
# . 12646065887601541794 . . . False False False en
# Fu 15118233380184131836 Xx F Fu True False True en
# on 5640369432778651323 xx o on True False False en
# 12 1124146173557384544 dd 1 12 False True False en
# - 9153284864653046197 - - - False False False en
# 12 1124146173557384544 dd 1 12 False True False en
# - 9153284864653046197 - - - False False False en
# 2017 12587536829529815270 dddd 2 017 False True False en
# : 11532473245541075862 : : : False False False en
# This 12943039165150086467 Xxxx T his True False True en
# is 3411606890003347522 xx i is True False False en
# a 11901859001352538922 x a a True False False en
# follow 14462500713227930305 xxxx f low True False False en
# up 2199259611705938403 xx u up True False False en
# spontaneous 8610553711004517296 xxxx s ous True False False en
# report 2729752284408055516 xxxx r ort True False False en
# concerning 13255496768650326488 xxxx c ing True False False en
# a 11901859001352538922 x a a True False False en
# female 194700782214550345 xxxx f ale True False False en
# patient 14577208587912523278 xxxx p ent True False False en
# . 12646065887601541794 . . . False False False en
# Concomitant 3769679768943967607 Xxxxx C ant True False True en
# medication 13479940910518016904 xxxx m ion True False False en
# was 9921686513378912864 xxx w was True False False en
# not 447765159362469301 xxx n not True False False en
# reported 11181246799942687462 xxxx r ted True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# patient 14577208587912523278 xxxx p ent True False False en
# received 8054871301319024843 xxxx r ved True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# for 16037325823156266367 xxx f for True False False en
# asthma 13804933907730890588 xxxx a hma True False False en
# via 17875975611192538924 xxx v via True False False en
# prescription 9002369395942733371 xxxx p ion True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# visited 11749534953085588517 xxxx v ted True False False en
# a 11901859001352538922 x a a True False False en
# doctor 18058202148154971361 xxxx d tor True False False en
# for 16037325823156266367 xxx f for True False False en
# examination 17851461254782948290 xxxx e ion True False False en
# on 5640369432778651323 xx o on True False False en
# an 15099054000809333061 xx a an True False False en
# unspecified 6741031536870065567 xxxx u ied True False False en
# date 15387552459474943870 xxxx d ate True False False en
# after 13428508259213873547 xxxx a ter True False False en
# she 6740321247510922449 xxx s she True False False en
# received 8054871301319024843 xxxx r ved True False False en
# Symbicort 14055695076967182582 Xxxxx S ort True False True en
# for 16037325823156266367 xxx f for True False False en
# a 11901859001352538922 x a a True False False en
# period 8930149225908759990 xxxx p iod True False False en
# . 12646065887601541794 . . . False False False en
# The 5059648917813135842 Xxx T The True False True en
# result 16479863421078305451 xxxx r ult True False False en
# of 886050111519832510 xx o of True False False en
# tracheoscopy 2786650462967112076 xxxx t opy True False False en
# examination 17851461254782948290 xxxx e ion True False False en
# showed 8950418246763676919 xxxx s wed True False False en
# that 4380130941430378203 xxxx t hat True False False en
# there 2112642640949226496 xxxx t ere True False False en
# was 9921686513378912864 xxx w was True False False en
# candida 14288947980135000626 xxxx c ida True False False en
# albicans 10990917657302772228 xxxx a ans True False False en
# infection 12354069391853095836 xxxx i ion True False False en
# in 3002984154512732771 xx i in True False False en
# her 4115755726172261197 xxx h her True False False en
# lung 14280935251206859071 xxxx l ung True False False en
# and 2283656566040971221 xxx a and True False False en
# the 7425985699627899538 xxx t the True False False en
# result 16479863421078305451 xxxx r ult True False False en
# of 886050111519832510 xx o of True False False en
# sputum 293119958153311504 xxxx s tum True False False en
# examination 17851461254782948290 xxxx e ion True False False en
# showed 8950418246763676919 xxxx s wed True False False en
# that 4380130941430378203 xxxx t hat True False False en
# there 2112642640949226496 xxxx t ere True False False en
# was 9921686513378912864 xxx w was True False False en
# monilial 7058579322075999043 xxxx m ial True False False en
# infection 12354069391853095836 xxxx i ion True False False en
# in 3002984154512732771 xx i in True False False en
# her 4115755726172261197 xxx h her True False False en
# oropharynx 17795721333051958783 xxxx o ynx True False False en
# . 12646065887601541794 . . . False False False en
# She 5252949303365547547 Xxx S She True False True en
# visited 11749534953085588517 xxxx v ted True False False en
# a 11901859001352538922 x a a True False False en
# doctor 18058202148154971361 xxxx d tor True False False en
# and 2283656566040971221 xxx a and True False False en
# the 7425985699627899538 xxx t the True False False en
# doctor 18058202148154971361 xxxx d tor True False False en
# did 13583488448875926965 xxx d did True False False en
# nt 9353232606613764737 xx n nt True False False en
# give 11640825575873464194 xxxx g ive True False False en
# the 7425985699627899538 xxx t the True False False en
# treatment 17998780750743588112 xxxx t ent True False False en
# . 12646065887601541794 . . . False False False en
# Information 7262725514246706477 Xxxxx I ion True False True en
# concerning 13255496768650326488 xxxx c ing True False False en
# new 4753564829687343602 xxx n new True False False en
# AEs 17773817688656105750 XXx A AEs True False False en
# of 886050111519832510 xx o of True False False en
# ’candida 7532090644163136144 ’xxxx ’ ida False False False en
# albicans 10990917657302772228 xxxx a ans True False False en
# infection 12354069391853095836 xxxx i ion True False False en
# in 3002984154512732771 xx i in True False False en
# her 4115755726172261197 xxx h her True False False en
# lung 14280935251206859071 xxxx l ung True False False en
# and 2283656566040971221 xxx a and True False False en
# ’monilial 6756949303980709534 ’xxxx ’ ial False False False en
# infection 12354069391853095836 xxxx i ion True False False en
# in 3002984154512732771 xx i in True False False en
# her 4115755726172261197 xxx h her True False False en
# oropharynx 17795721333051958783 xxxx o ynx True False False en
# was 9921686513378912864 xxx w was True False False en
# added 9384810846185141164 xxxx a ded True False False en
# . 12646065887601541794 . . . False False False en
#
#  962983613142996970
#
#
#  False False False en

# %% [markdown]
# The mapping of words to hashes doesn't depend on any state. To make sure each value is unique, spaCy uses a hash function to calculate the hash based on the word string. This also means that the hash for "coffee" will always be the same, no matter which model you're using or how you've configured spaCy.

# %% [markdown]
# However, hashes cannot be reversed and there's no way to resolve 3197928453018144401 back to "coffee". All spaCy can do is look it up in the vocabulary. That's why you always need to make sure all objects you create have access to the same vocabulary. If they don't, spaCy might not be able to find the strings it needs.

# %%
from spacy.tokens import Doc
from spacy.vocab import Vocab

doc = nlp(u'I love coffee') # original Doc
print(doc.vocab.strings[u'coffee'])  # 3197928453018144401
print(doc.vocab.strings[3197928453018144401])  # 'coffee' 👍

empty_doc = Doc(Vocab())  # new Doc with empty Vocab
# empty_doc.vocab.strings[3197928453018144401] will raise an error :(

empty_doc.vocab.strings.add(u'coffee')  # add "coffee" and generate hash
print(empty_doc.vocab.strings[3197928453018144401])  # 'coffee' 👍

new_doc = Doc(doc.vocab)  # create new doc with first doc's vocab
print(new_doc.vocab.strings[3197928453018144401])  # 'coffee' 👍
# Out:
# 3197928453018144401
# coffee
# coffee
# coffee

# %% [markdown]
# ### Serialization

# %% [markdown]
# If you've been modifying the pipeline, vocabulary, vectors and entities, or made updates to the model, you'll eventually want to save your progress – for example, everything that's in your nlp object. This means you'll have to translate its contents and structure into a format that can be saved, like a file or a byte string. This process is called serialization. spaCy comes with built-in serialization methods and supports the Pickle protocol.
#
# WHAT'S PICKLE?
# Pickle is Python's built-in object persistance system. It lets you transfer arbitrary Python objects between processes. This is usually used to load an object to and from disk, but it's also used for distributed computing, e.g. with PySpark or Dask. When you unpickle an object, you're agreeing to execute whatever code it contains. It's like calling eval() on a string – so don't unpickle objects from untrusted sources.
